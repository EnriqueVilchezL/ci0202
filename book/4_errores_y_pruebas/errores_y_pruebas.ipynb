# %% [markdown]
# # Principios de Informática: Errores y Pruebas 🐞
# ### A la caza de pulgas (bugs)
# **Curso:** Principios de Informática
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/ci0202/blob/main/book/4_errores_y_pruebas/errores_y_pruebas.ipynb)
#
# ---
#
# ## 🗺️ Objetivos y contenidos
#
# Este notebook es una guía interactiva para diferenciar entre errores lógicos y errores de ejecución en programación, comprender la importancia de corregir y probar tus programas, y aplicar pruebas de software de caja negra para asegurar el correcto funcionamiento del código.
#
# > "Detectar y corregir errores es una habilidad esencial para cualquier programador."
#
# **Importancia:**
# - Los errores son inevitables en la programación, pero saber identificarlos y corregirlos te hará mejor programador.
# - Las pruebas te ayudan a garantizar que tu código funciona como esperas y a evitar sorpresas.
#
# **Contenidos:**
# 1. Conceptos de error lógico y error de ejecución
# 2. Importancia de la corrección de programas
# 3. Pruebas de software de caja negra

# %% [markdown]
# ---
#
# ## 1. Conceptos de error lógico y error de ejecución
#
# ---
#
# En programación, un **error** o **bug** es un defecto en el código que causa que un programa se comporte de manera inesperada o incorrecta. No importa cuán bueno seas programando, ¡los errores siempre aparecerán! La clave es saber cómo encontrarlos y corregirlos.

# %% [markdown]
# Existen principalmente dos tipos de errores con los que te encontrarás:
#
# ### ❌ Errores de Ejecución (Runtime Errors)
# Estos errores detienen el programa por completo. Ocurren cuando el programa intenta hacer algo que es imposible.
#
# ---

# %%
# Ejemplo de error de ejecución (Runtime Error):
# Intentar acceder a un índice fuera de rango en una lista
lista = [1, 2, 3]
print(lista[5])  # Esto causará un IndexError en tiempo de ejecución

# %% [markdown]
# ### 🤯 Errores Lógicos (Logical Errors)
#
# Estos son los más difíciles de detectar. El programa se ejecuta sin problemas, pero el resultado es incorrecto porque la lógica del código está mal.
#
# ---

# %%
# Area de rectangulo
base = 10
altura = 3
base * altura / 2 # debería ser base * altura

# %% [markdown]
# ## ❌ Errores de Ejecución
#
# Imagine que le pide a un robot que divida 10 manzanas entre 0 personas. El robot se quedaría "congelado" porque es una tarea imposible. ¡Eso es un error de ejecución!
#
# Python avisa de estos errores con un mensaje claro que dice qué salió mal y en qué línea de código.
#
# ---

# %%
# Ejemplo de error de ejecución: Dividir por cero
numerador = 10
denominador = 0
# La siguiente línea causará un error y detendrá el programa
# print(numerador / denominador)

# %%
# Corrección: Verificar antes de dividir
numerador = 10
denominador = 0

if denominador != 0:
  print(numerador / denominador)
else:
  print("No se puede dividir por cero.")

# %% [markdown]
# ### ⚠️ Excepciones en Python
#
# Cuando ocurre un error de ejecución, Python genera una **excepción**. Una excepción es un objeto especial que indica que algo inesperado sucedió durante la ejecución del programa.
#
# Algunos tipos comunes de excepciones en Python son:
#
# - `ZeroDivisionError`: Intentar dividir por cero.
# - `IndexError`: Acceder a un índice fuera del rango de una lista.
# - `TypeError`: Usar un tipo de dato incorrecto en una operación.
# - `ValueError`: Usar un valor inapropiado para una operación.
# - `NameError`: Usar una variable que no ha sido definida.

# %%
resultado = 10 / 0  # Esto causará un ZeroDivisionError en tiempo de ejecución

# %%
lista = [1, 2, 3, 4, 5]
print(lista[10])  # Esto causará un IndexError en tiempo de ejecución

# %%
1 + "Hola"  # Esto causará un TypeError en tiempo de ejecución

# %%
int("Hola")  # Esto causará un ValueError en tiempo de ejecución

# %%
print(mi_variable_no_definida)  # Esto causará un NameError en tiempo de ejecución

# %% [markdown]
# ## 🤯 Errores Lógicos
#
# Estos errores son como seguir una receta de cocina al pie de la letra, pero la receta tenía un error y en lugar de azúcar usaste sal. El pastel se verá como un pastel, pero el sabor será... ¡inesperado!
#
# El programa no se detiene, pero el resultado no es el que esperabas. Estos errores requieren que revises la lógica de tu código paso a paso.
#
# ---

# %%
# Ejemplo de error lógico (Logical Error):
# Calcular el área de un triángulo, pero usar la fórmula incorrecta
base = 10
altura = 5
# Fórmula incorrecta: área = base * altura (debería ser base * altura / 2)
area = base * altura
print(f'Área calculada (incorrecta): {area}')

# %%
# Ejemplo de error lógico: Calcular un promedio incorrectamente
# El objetivo es calcular el promedio de 3 números
numero1 = 10
numero2 = 20
numero3 = 30

# Error lógico: se divide por 2 en lugar de 3
promedio_incorrecto = (numero1 + numero2 + numero3) / 2
print(f"Promedio incorrecto: {promedio_incorrecto}")

# %%
# Corrección:
promedio_correcto = (numero1 + numero2 + numero3) / 3
print(f"✅ Promedio correcto: {promedio_correcto}")

# %% [markdown]
# #### ⚔️ Ejercicio: Puntos de vida
#
# Hay que hacer un programa que, dada una cantidad de vida de un personaje en un videojuego, suponga que es atacado con el ataque `Embestida de espada`. Este ataque hace 10 de daño al personaje.
#
# Un programador experimentado hizo este código, pero cuenta con un error lógico. Identifique y corrija el error.
#
# ---

# %%
dano_de_espada = 10
vida_inicial = 100
vida_final = dano_de_espada - vida_inicial

print(f"La vida inicial de Sam es: {vida_inicial}")
print(f"Sam recibe {dano_de_espada} puntos de daño...")
print(f"La vida final de Sam es: {vida_final}")

# %% [markdown]
# ---
#
# ## 2. Importancia de la corrección de programas
#
# ---
#
# Programar sin probar es como construir un puente y cruzarlo sin verificar si es seguro. Las **pruebas** son el proceso de verificar que tu código hace lo que se supone que debe hacer y que no tiene errores.
#
# ### Ejemplos reales donde no probar salió caro:
#
# - **[NASA Mars Climate Orbiter (1999)](https://www.jpl.nasa.gov/missions/mars-climate-orbiter/):** Una sonda espacial se perdió porque un equipo usó unidades imperiales y otro métricas. El error no fue detectado en pruebas y costó 125 millones de dólares.
# - **[Ariane 5 (1996)](https://www.esa.int/Newsroom/Press_Releases/Ariane_501_-_Presentation_of_Inquiry_Board_report):** Un cohete europeo explotó segundos después de despegar por un error de software no probado en condiciones reales. Pérdidas: 370 millones de dólares.
# - **[Therac-25 (década de 1980)](https://ethicsunwrapped.utexas.edu/case-study/therac-25?lang=es):** Una máquina de radioterapia administró dosis letales a pacientes por errores de software no detectados en pruebas rigurosas.
# - **[Knight Capital (2012)](https://www.cio.com/article/286790/software-testing-lessons-learned-from-knight-capital-fiasco.html):** Una empresa financiera perdió 440 millones de dólares en 45 minutos por un error en el software de trading que no fue probado adecuadamente.

# %% [markdown]
# ---
#
# ## 3. Pruebas de software de caja negra
#
# ---
#
# ### 📦 Pruebas de Caja Negra (Black-Box Testing)
#
# Una forma común de probar es la **prueba de caja negra**. Imagina que tienes una máquina (una "caja negra"), pero no puedes ver cómo funciona por dentro. Solo puedes ponerle entradas y ver qué salidas produce.
#
# En las pruebas de caja negra, no nos importa *cómo* está escrito el código. Solo nos enfocamos en si para una **entrada** dada, obtenemos la **salida esperada**.
#
# Entrada -> **[Caja Negra]** -> Salida
# ---

# %% [markdown]
# Suponga que tiene una función que calcula el descuento para una tienda. Hay que probarla usando la técnica de caja negra.
#
# ---

# %%
def calcular_precio_final(precio_original: float, categoria_cliente: str) -> float:
  """
  Calcula el precio final aplicando un descuento basado en la categoría del cliente.
  - 'normal': 10% de descuento
  - 'vip': 20% de descuento
  - 'premium': 30% de descuento
  """
  if categoria_cliente == "normal":
    descuento = 0.10
  elif categoria_cliente == "vip":
    descuento = 0.20
  elif categoria_cliente == "premium":
    descuento = 0.30
  else:
    descuento = 0.0
  
  return precio_original * (1 - descuento)

# %% [markdown]
# ### Pasos para la Prueba de Caja Negra
#
# 1.  **Entender qué debe hacer la función:** La función aplica un descuento según la categoría del cliente.
# 2.  **Definir casos de prueba:** Piense en diferentes entradas que se le podrían dar y cuál debería ser la salida.
#
#     * **Caso Normal:** Una entrada típica y esperada.
#         * `precio_original = 100`, `categoria_cliente = "vip"` -> `salida esperada = 80`
#     * **Caso de Borde:** Un valor en el límite de una condición.
#         * `precio_original = 0`, `categoria_cliente = "normal"` -> `salida esperada = 0`
#     * **Caso de Error:** Una entrada que no debería funcionar o que debería ser manejada de alguna forma.
#         * `precio_original = 100`, `categoria_cliente = "invitado"` -> `salida esperada = 100`

# %% [markdown]
# Ahora, se escribe el código para probar la función con los casos que se definieron.
#
# ---

# %%
# Escribe aquí tus pruebas
# Ejemplo de cómo probar un caso:
precio_calculado = calcular_precio_final(100, "vip")
print(f"Probando cliente 'vip': Precio esperado = 80, Precio calculado = {precio_calculado}")

# ¡Añade más pruebas!

# %% [markdown]
# ### ✅ Solución de las Pruebas
#
# Una forma de automatizar las pruebas es usando `assert`, que verifica si una condición es verdadera. Si no lo es, detiene el programa y muestra un error.
#
# ---

# %%
assert True

# %%
assert False

# %%
assert 10 > 20

# %%
# Caso Normal
assert calcular_precio_final(100, "normal") == 90
assert calcular_precio_final(200, "vip") == 160
assert calcular_precio_final(1000, "premium") == 700

# Caso de Borde
assert calcular_precio_final(0, "normal") == 0

# Caso de Error
assert calcular_precio_final(100, "invitado") == 100
assert calcular_precio_final(100, "") == 100

print("✅ ¡Todas las pruebas pasaron exitosamente!")

# %% [markdown]
# ## 🎯 Resumen y Ejercicios de Repaso
#
# Se presentó una síntesis de los errores básicos y pruebas en Python.
#
# ### 📚 Contenidos revisados
#
# 1. **Errores en programación:**
#    - Diferencia entre errores de ejecución (que detienen el programa) y errores lógicos (el programa corre pero da resultados incorrectos).
#    - Ejemplos prácticos de ambos tipos de errores.
#
# 2. **Importancia de la corrección y pruebas:**
#    - Por qué es fundamental probar el código antes de usarlo en situaciones reales.
#    - Casos históricos donde la falta de pruebas causó pérdidas millonarias o daños a personas.
#
# 3. **Pruebas de caja negra:**
#    - Qué es una prueba de caja negra y cómo se aplica en la práctica.
#    - Cómo diseñar y ejecutar casos de prueba para funciones.
#
# ---

# %% [markdown]
# ## 📝 Ejercicios de Práctica
#
# A continuación se proponen ejercicios organizados por tema para consolidar los conceptos.

# %% [markdown]
# ### Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade --force-reinstall notebook-cell-tester --q

# %% [markdown]
# -----
#
# ### 1️⃣ **Ejercicios: Errores Lógicos y de Ejecución**

# %% [markdown]
# **Ejercicio 1.1 - Lógica del Promedio**
#
# El siguiente código intenta calcular el promedio de tres números. El resultado esperado para los valores dados (a=10, b=20, c=30) es **20**. Sin embargo, el código tiene un error lógico.
#
# Pregunta: ¿Cuál es el error y cómo se puede corregir?
#
# Corrija el error directamente en el código de la siguiente celda.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Recuerde el orden de operadores en Python: la multiplicación y división tienen mayor precedencia que la suma.
# - Verifique si `a + b + c / 3` realmente representa `(a + b + c) / 3`.
# - Use paréntesis para forzar el orden de las operaciones que necesita.
#
# </details>

# %%
a = 10
b = 20
c = 30
promedio = a + b + c / 3
print(promedio)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'promedio' tiene el valor correcto", test_type="variable", variable_name="promedio",
                 validator=lambda v: abs(v - 20) < 1e-9,
                 success_message="'promedio' tiene el valor correcto (20).",
                 error_message="'promedio' no vale 20. El error es de precedencia: '/' se ejecuta antes que '+', así que solo 'c' se estaba dividiendo entre 3. Encierre 'a + b + c' entre paréntesis antes de dividir."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
a = 10
b = 20
c = 30
promedio = (a + b + c) / 3
print(promedio)

# %% [markdown]
# **Ejercicio 1.2 - Conversión de Moneda**
#
# Este código busca convertir una cantidad en dólares a euros. Con el valor actual ($1 = 0.93€), el resultado esperado para $100 dólares es 93 €. El código no produce el resultado correcto.
#
# Pregunta: ¿Qué está mal en la operación y cuál es la solución?
#
# Corrija el error directamente en el código de la siguiente celda.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Piense en qué operación matemática representa convertir una cantidad usando una tasa de cambio.
# - Revise si `+` es la operación correcta para calcular euros a partir de dólares y una tasa.
# - Recuerde que una conversión de unidades normalmente es una multiplicación, no una suma.
#
# </details>

# %%
dolares = 100
tasa_cambio = 0.93
euros = dolares + tasa_cambio
print(euros)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'euros' tiene el valor correcto", test_type="variable", variable_name="euros",
                 validator=lambda v: abs(v - 93) < 1e-9,
                 success_message="'euros' tiene el valor correcto (93).",
                 error_message="'euros' no vale 93. La conversión de moneda es una multiplicación (cantidad * tasa), no una suma. Use el operador '*' en lugar de '+'."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
dolares = 100
tasa_cambio = 0.93
euros = dolares * tasa_cambio
print(euros)

# %% [markdown]
# **Ejercicio 1.3 - Cálculos de Interés**
#
# El siguiente fragmento de código calcula el interés simple sobre un capital inicial durante un período de tiempo. La fórmula correcta es I = C * r * t, donde I es el interés, C es el capital, r es la tasa de interés y t es el tiempo. Con los valores dados (C=1000, r=0.05 (5%), t=2), el resultado esperado es 100. El código actual genera un resultado incorrecto.
#
# Pregunta: ¿Qué error se produce y cómo lo resolvería para obtener el resultado correcto sabiendo que **no puede cambiar los valores iniciales de las variables**?
#
# Corrija el error directamente en el código de la siguiente celda (sin modificar las 3 primeras líneas de asignación).

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Revise el tipo de dato de `tasa_interes` con `type(tasa_interes)` antes de usarla en la operación.
# - Note que `tasa_interes` es una cadena de texto (`str`), no un número.
# - Use `float()` para convertir la cadena a un número decimal antes de multiplicar.
# - No puede modificar las primeras 3 líneas, así que la conversión debe hacerse en la línea del cálculo.
#
# </details>

# %%
capital = 1000
tasa_interes = "0.05"
tiempo = 2
interes = capital * tasa_interes * tiempo
print(interes)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'interes' tiene el valor correcto", test_type="variable", variable_name="interes",
                 validator=lambda v: isinstance(v, (int, float)) and abs(v - 100) < 1e-9,
                 success_message="'interes' tiene el valor numérico correcto (100).",
                 error_message="'interes' no vale 100 (numérico). 'tasa_interes' es un texto (\"0.05\"), así que la multiplicación no falla pero produce un resultado incorrecto (repite el texto). Convierta 'tasa_interes' a número con float() antes de multiplicar."),
    ]),
    TestSection("Sección 2 — Variables y estado", [
        TestCase(name="'tasa_interes' no fue modificada", test_type="variable", variable_name="tasa_interes",
                 validator=lambda v: v == "0.05",
                 success_message="'tasa_interes' conserva su valor original de texto '0.05'.",
                 error_message="'tasa_interes' ya no vale el texto '0.05'. No modifique las 3 líneas de asignación iniciales; convierta el valor únicamente al usarlo en el cálculo."),
    ]),
    TestSection("Sección 3 — Estilo de código", [
        TestCase(name="Usa float() para convertir 'tasa_interes'", test_type="regex", pattern=r"float\(\s*tasa_interes\s*\)",
                 success_message="Se usó float(tasa_interes) para convertir el texto a número.",
                 error_message="No se detectó float(tasa_interes). Convierta 'tasa_interes' a número con float() dentro del cálculo de 'interes'."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
capital = 1000
tasa_interes = "0.05"
tiempo = 2
interes = capital * float(tasa_interes) * tiempo
print(interes)

# %% [markdown]
# **Ejercicio 1.4 - Concatenación de Textos y Números**
#
# Este código intenta crear una cadena de texto que incluya un número, pero se produce un error de ejecución.
#
# Pregunta: ¿Cuál es el error y cómo lo solucionaría para que el mensaje se imprima correctamente?
#
# Corrija el error directamente en el código de la siguiente celda.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Revise qué tipo de dato tiene `edad` antes de concatenarla con cadenas de texto.
# - Python no permite unir (`+`) una cadena de texto con un número directamente.
# - Considere usar un f-string (`f"..."`) o convertir `edad` con `str()`.
#
# </details>

# %%
nombre = "María"
edad = 25
mensaje = "Hola, mi nombre es " + nombre + " y tengo " + edad + " años."
print(mensaje)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'mensaje' tiene el texto correcto", test_type="variable", variable_name="mensaje",
                 validator=lambda v: v == "Hola, mi nombre es María y tengo 25 años.",
                 success_message="'mensaje' contiene el texto correcto.",
                 error_message="'mensaje' no es 'Hola, mi nombre es María y tengo 25 años.'. No se puede concatenar un str con un int directamente; convierta 'edad' a texto con str(), o use un f-string."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
nombre = "María"
edad = 25
mensaje = f"Hola, mi nombre es {nombre} y tengo {edad} años."
print(mensaje)

# %% [markdown]
# -----
#
# ### 2️⃣ **Ejercicios: La Importancia de las Pruebas**

# %% [markdown]
# **Ejercicio 2.1 - Prueba de Cálculo de Descuento**
#
# Se tiene un bloque de código que calcula el precio con descuento. El código no valida que `descuento_porcentaje` esté entre 0% y 100%, ni que `precio` sea positivo.
#
# Cambie los valores de `precio` y/o `descuento_porcentaje`, de modo que `precio_final` resulte **negativo**, revelando así el error lógico. **No corrija el código todavía**, solo cambie los valores iniciales.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - No necesita corregir el código todavía, solo elegir valores de entrada que lo "rompan".
# - Piense qué pasa si `descuento_porcentaje` es mayor a 100.
# - Calcule a mano cuánto sería `descuento_monto` y `precio_final` con esos valores para confirmar que da negativo.
#
# </details>

# %%
precio = 100
descuento_porcentaje = 20
descuento_monto = precio * (descuento_porcentaje / 100)
precio_final = precio - descuento_monto
print(f"El precio final es: {precio_final}")

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'precio_final' revela el error lógico (es negativo)", test_type="variable", variable_name="precio_final",
                 validator=lambda v: v < 0,
                 success_message="'precio_final' es negativo: logró revelar el error lógico del código.",
                 error_message="'precio_final' no es negativo. Pruebe con un 'descuento_porcentaje' mayor a 100 (por ejemplo 150), o con un 'precio' negativo, para revelar que el código no valida esos casos."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
precio = 100
descuento_porcentaje = 150  # un descuento mayor a 100% no debería ser válido
descuento_monto = precio * (descuento_porcentaje / 100)
precio_final = precio - descuento_monto
print(f"El precio final es: {precio_final}")  # -50: revela que falta validar el descuento

# %% [markdown]
# **Ejercicio 2.2 - Corrección de descuento**
#
# Corrija el código para que, si se ingresan números negativos en `precio` o `descuento_porcentaje`, se conviertan en positivos (con `abs()`) antes de hacer los cálculos.
#
# Además, explique con sus propias palabras cuál **otro** error podría ocasionarse en este código, aparte del de los números negativos (piense en el ejercicio anterior). Guarde su explicación como texto en una variable llamada `otro_error_explicacion`.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use la función `abs()` sobre `precio` y `descuento_porcentaje` antes de calcular el descuento.
# - Guarde el resultado de vuelta en las mismas variables antes de continuar con el cálculo.
# - Para el otro error, recuerde el ejercicio 2.1: el código tampoco valida que el descuento esté entre 0% y 100%.
# - Guarde su explicación como una cadena de texto en la variable `otro_error_explicacion`.
#
# </details>

# %%
# ====== NO MODIFICAR ESTE BLOQUE ======
precio = -100
descuento_porcentaje = -20
# ====== NO MODIFICAR ESTE BLOQUE ======

# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'precio_final' maneja correctamente los negativos", test_type="variable", variable_name="precio_final",
                 validator=lambda v: abs(v - 80) < 1e-6,
                 success_message="'precio_final' vale 80: los valores negativos se convirtieron correctamente con abs().",
                 error_message="'precio_final' no vale 80. Use abs() sobre 'precio' y 'descuento_porcentaje' antes de calcular 'descuento_monto' y 'precio_final'."),
        TestCase(name="Se explica el otro posible error", test_type="variable", variable_name="otro_error_explicacion",
                 validator=lambda v: isinstance(v, str) and len(v.strip()) >= 15,
                 success_message="Se incluyó una explicación del otro posible error.",
                 error_message="'otro_error_explicacion' debe ser un texto explicando el otro error posible (pista: ¿qué pasa si el descuento supera el 100%, incluso ya sin signos negativos?)."),
    ]),
    TestSection("Sección 2 — Variables y estado", [
        TestCase(name="'precio' original no fue reescrita a mano", test_type="variable", variable_name="precio",
                 validator=lambda v: v == 100,
                 success_message="'precio' terminó en 100, resultado de aplicar abs() a -100.",
                 error_message="'precio' debería terminar en 100 tras aplicarle abs(). No escriba 'precio = 100' directamente; use abs(precio)."),
    ]),
    TestSection("Sección 3 — Estilo de código", [
        TestCase(name="Usa abs()", test_type="regex", pattern=r"abs\(",
                 success_message="Se utiliza abs() para manejar los valores negativos.",
                 error_message="No se detectó el uso de abs(). Úselo para convertir 'precio' y 'descuento_porcentaje' en valores positivos."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
precio = -100
descuento_porcentaje = -20

precio = abs(precio)
descuento_porcentaje = abs(descuento_porcentaje)

descuento_monto = precio * (descuento_porcentaje / 100)
precio_final = precio - descuento_monto
print(f"El precio final es: {precio_final}")

otro_error_explicacion = (
    "El código tampoco valida que 'descuento_porcentaje' esté entre 0 y 100. "
    "Si el descuento supera el 100% (por ejemplo 150), 'precio_final' resultaría "
    "negativo, aunque los valores ya no tengan signo negativo."
)

# %% [markdown]
# -----
#
# ### 3️⃣ **Ejercicios: Pruebas de Caja Negra**

# %% [markdown]
# **Ejercicio 3.1 - Caja negra para el Cálculo de Área**
#
# Dadas las siguientes entradas para calcular el área de un triángulo (área = base * altura / 2), determine cuál debería ser la salida correcta para cada caso:
#
# 1. Altura: 20, Base: 30 → guarde la respuesta en `salida_esperada_1`
# 2. Altura: 10, Base: 12 → guarde la respuesta en `salida_esperada_2`
# 3. Altura: 8, Base: 5 → guarde la respuesta en `salida_esperada_3`
# 4. Altura: 15, Base: 6 → guarde la respuesta en `salida_esperada_4`
# 5. Altura: 25, Base: 14 → guarde la respuesta en `salida_esperada_5`

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use la fórmula área = base * altura / 2 para cada caso.
# - Calcule cada resultado con una expresión aritmética simple en Python.
# - Asigne cada resultado a la variable indicada (`salida_esperada_1`, `salida_esperada_2`, etc.), respetando los nombres exactos.
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

esperado = {
    "salida_esperada_1": 300,
    "salida_esperada_2": 60,
    "salida_esperada_3": 20,
    "salida_esperada_4": 45,
    "salida_esperada_5": 175,
}

def hace_validador(valor_esperado):
    return lambda v: abs(v - valor_esperado) < 1e-6

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name=f"'{nombre}' tiene el valor correcto",
            test_type="variable",
            variable_name=nombre,
            validator=hace_validador(valor),
            success_message=f"'{nombre}' tiene el valor correcto ({valor}).",
            error_message=f"'{nombre}' no vale {valor}. Recuerde que el área de un triángulo es base * altura / 2.",
        )
        for nombre, valor in esperado.items()
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
salida_esperada_1 = 30 * 20 / 2  # 300
salida_esperada_2 = 12 * 10 / 2  # 60
salida_esperada_3 = 5 * 8 / 2    # 20
salida_esperada_4 = 6 * 15 / 2   # 45
salida_esperada_5 = 14 * 25 / 2  # 175

# %% [markdown]
# **Ejercicio 3.2 - Tipo de Prueba para Lógica**
#
# Se desea diseñar un sistema que calcule el precio final de un pedido, considerando varios factores:
#
# 1. Precio base del producto: cualquier número positivo, puede incluir decimales.
# 2. Descuento por volumen:
#    - Si la cantidad comprada es mayor a 10 unidades, aplica un descuento del 5% sobre el precio total.
#    - Si la cantidad es mayor a 20 unidades, aplica un descuento del 10% sobre el precio total (en vez del anterior).
#    - Si la cantidad es mayor a 50 unidades, aplica un descuento del 20% sobre el precio total (en vez de los anteriores).
# 3. Bonificación especial:
#    - Si el precio total después del descuento es mayor a 1000, se aplica un bono fijo de 50 unidades monetarias que se resta del precio final.
#
# **Sin escribir código que resuelva el problema**, complete la salida esperada para los siguientes 3 casos de prueba, razonando a mano con las reglas anteriores:
#
# | Precio unitario | Cantidad | Salida esperada |
# |-----------------|---------|----------------|
# | 50              | 5       | `salida_caso_1` |
# | 25.5            | 15      | `salida_caso_2` |
# | 40              | 55      | `salida_caso_3` |
#
# Además, proponga **5 casos de prueba adicionales**: guárdelos como una lista de 5 tuplas `(precio_unitario, cantidad, salida_esperada)` en una variable llamada `casos_adicionales`, asegurándose de que la salida esperada de cada uno sea consistente con las reglas descritas.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - No escriba código que resuelva el problema completo; solo razone las reglas paso a paso para cada caso.
# - Aplique el descuento por volumen según el rango de cantidad correcto (más de 10, más de 20, o más de 50 unidades) — solo se aplica el descuento más alto que corresponda, no varios a la vez.
# - Después de aplicar el descuento, revise si el precio total supera 1000 para saber si debe restar el bono de 50.
# - Para los casos adicionales, guarde una lista de 5 tuplas `(precio_unitario, cantidad, salida_esperada)` en `casos_adicionales`, cubriendo distintos rangos de descuento y el límite del bono.
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

def precio_segun_reglas(precio_unitario, cantidad):
    total = precio_unitario * cantidad
    if cantidad > 50:
        descuento = 0.20
    elif cantidad > 20:
        descuento = 0.10
    elif cantidad > 10:
        descuento = 0.05
    else:
        descuento = 0.0
    total = total * (1 - descuento)
    if total > 1000:
        total -= 50
    return total

casos_tabla = {
    "salida_caso_1": (50, 5),
    "salida_caso_2": (25.5, 15),
    "salida_caso_3": (40, 55),
}

def hace_validador_tabla(precio_unitario, cantidad):
    esperado = precio_segun_reglas(precio_unitario, cantidad)
    return lambda v: abs(v - esperado) < 1e-6

def valida_casos_adicionales(v):
    if not isinstance(v, list) or len(v) != 5:
        return False
    for caso in v:
        if not isinstance(caso, (tuple, list)) or len(caso) != 3:
            return False
        precio_unitario, cantidad, salida_esperada = caso
        esperado = precio_segun_reglas(precio_unitario, cantidad)
        if abs(salida_esperada - esperado) > 1e-6:
            return False
    return True

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(
            name=f"'{nombre}' tiene la salida correcta",
            test_type="variable",
            variable_name=nombre,
            validator=hace_validador_tabla(*entrada),
            success_message=f"'{nombre}' tiene la salida esperada correcta.",
            error_message=f"'{nombre}' no coincide con la salida esperada aplicando las reglas de descuento y bonificación descritas (entrada: precio_unitario={entrada[0]}, cantidad={entrada[1]}).",
        )
        for nombre, entrada in casos_tabla.items()
    ]),
    TestSection("Sección 2 — Casos de prueba adicionales", [
        TestCase(
            name="'casos_adicionales' tiene 5 casos consistentes con las reglas",
            test_type="variable",
            variable_name="casos_adicionales",
            validator=valida_casos_adicionales,
            success_message="Los 5 casos adicionales son consistentes con las reglas de descuento y bonificación.",
            error_message="'casos_adicionales' debe ser una lista de 5 tuplas (precio_unitario, cantidad, salida_esperada), donde cada salida_esperada sea consistente con las reglas de descuento por volumen y bonificación descritas en el enunciado.",
        ),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
# Caso 1: precio_unitario=50, cantidad=5 -> cantidad <= 10, sin descuento
#   total = 50 * 5 = 250 (no supera 1000, sin bono)
salida_caso_1 = 250

# Caso 2: precio_unitario=25.5, cantidad=15 -> cantidad > 10, descuento 5%
#   total = 25.5 * 15 = 382.5; con descuento: 382.5 * 0.95 = 363.375 (sin bono)
salida_caso_2 = 363.375

# Caso 3: precio_unitario=40, cantidad=55 -> cantidad > 50, descuento 20%
#   total = 40 * 55 = 2200; con descuento: 2200 * 0.80 = 1760
#   supera 1000, se resta el bono: 1760 - 50 = 1710
salida_caso_3 = 1710

# 5 casos adicionales, cubriendo cada rango de descuento y el límite del bono:
casos_adicionales = [
    (10, 1, 10),          # cantidad muy pequeña, sin descuento: 10*1 = 10
    (100, 11, 995),       # justo sobre el límite de 10 -> 5% de descuento; 100*11*0.95=1045, supera 1000 -> -50 = 995
    (100, 21, 1840),      # justo sobre el límite de 20 -> 10% de descuento; 100*21*0.90=1890, supera 1000 -> -50 = 1840
    (200, 51, 8110),      # justo sobre el límite de 50 -> 20% de descuento y bono: 200*51*0.80 - 50 = 8110
    (30, 40, 1030),       # descuento del 10% que aún así supera 1000 -> aplica el bono: 30*40*0.90 - 50 = 1030
]

# %% [markdown]
# -----
#
# ### 4️⃣ **Ejercicios Integrados**

# %% [markdown]
# **Ejercicio 4.1 - Corrección de Porcentaje**
#
# Un motor eléctrico convierte energía eléctrica en trabajo mecánico. La eficiencia se define como el porcentaje de energía útil respecto a la energía total consumida.
#
# El cálculo actual no devuelve la eficiencia correcta en porcentaje. Corrija el error para que el resultado sea 50.0 (%).
#
# Determine cuál es la operación incorrecta y cómo modificarla. Corrija el error directamente en el código de la siguiente celda.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Recuerde que un porcentaje se calcula como (parte / total) * 100.
# - Revise si la operación actual realmente divide la energía útil entre la energía total, o si hace otra cosa.
# - Corrija el orden de la multiplicación y la división para que el resultado sea 50.0.
#
# </details>

# %%
# ====== NO MODIFICAR ESTE BLOQUE ======
energia_total = 2000    # Energía consumida en Joules
energia_util = 1000     # Energía convertida en trabajo útil en Joules
# ====== NO MODIFICAR ESTE BLOQUE ======

eficiencia = energia_util * energia_total / 100
print(eficiencia)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'eficiencia' tiene el valor correcto", test_type="variable", variable_name="eficiencia",
                 validator=lambda v: abs(v - 50.0) < 1e-6,
                 success_message="'eficiencia' tiene el valor correcto (50.0%).",
                 error_message="'eficiencia' no vale 50.0. La eficiencia es (energía útil / energía total) * 100, no una multiplicación de ambas energías."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
energia_total = 2000
energia_util = 1000

eficiencia = energia_util / energia_total * 100
print(eficiencia)

# %% [markdown]
# **Ejercicio 4.2 - Corrección de Operación Aritmética**
#
# A continuación se muestra un bloque de código para elevar 3 a la potencia 5, que contiene un error lógico.
#
# Corrija el error lógico (sin cambiar los valores de `a` y `b`) y luego, escriba una prueba simple con `assert` para verificar que su corrección funciona.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Revise cuál variable representa la base y cuál el exponente en la operación `**`.
# - Piense en qué orden deben ir `a` y `b` para calcular "3 elevado a la 5" en vez de "5 elevado a la 3".
# - Use una sentencia `assert` con el valor 243 para verificar automáticamente su corrección.
#
# </details>

# %%
a = 5
b = 3
resultado = a ** b
print(resultado)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'resultado' tiene el valor correcto", test_type="variable", variable_name="resultado",
                 validator=lambda v: v == 243,
                 success_message="'resultado' vale 243 (3 elevado a la 5).",
                 error_message="'resultado' no vale 243. 'a' vale 5 y 'b' vale 3, pero se busca 3 elevado a la 5, es decir 'b ** a', no 'a ** b'."),
    ]),
    TestSection("Sección 2 — Estilo de código", [
        TestCase(name="Escribe una prueba con 'assert'", test_type="regex", pattern=r"assert\s+resultado",
                 success_message="Se escribió una prueba con 'assert' para verificar 'resultado'.",
                 error_message="No se detectó un 'assert' que verifique 'resultado'. Agregue una línea como 'assert resultado == 243'."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
a = 5
b = 3
resultado = b ** a
print(resultado)

assert resultado == 243, "3 elevado a la 5 debe ser 243"
print("✅ La prueba pasó correctamente.")

# %% [markdown]
# -----
#
# ### 5️⃣ **Ejercicios de Repaso**

# %% [markdown]
# **Ejercicio 5.1 - Corrección de Resultado Numérico**
#
# Un ingeniero químico está evaluando la eficiencia final de un experimento combinando varias contribuciones: la cantidad de reactivo A, la cantidad de reactivo B, un factor de corrección experimental, y la pérdida esperada en el proceso. El código de abajo (comentado, para que no se ejecute) va a dar un error de ejecución.
#
# **Sin ejecutar el código**, encuentre y explique el error de ejecución. Guarde el nombre de la excepción que ocurriría (como texto, por ejemplo `"ZeroDivisionError"`) en una variable llamada `tipo_de_error`, y una breve explicación en `explicacion`.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - No ejecute el código: calcule a mano el valor del denominador `(reactivo_A + perdida - constante)` con los valores dados.
# - Piense qué excepción ocurre en Python cuando se divide entre un número que da cero.
# - Guarde el nombre exacto de la excepción (como texto) en `tipo_de_error`, y su razonamiento en `explicacion`.
#
# </details>

# %%
# ====== NO MODIFICAR ESTE BLOQUE ======
reactivo_A = 5        # unidades de reactivo A
reactivo_B = 10       # unidades de reactivo B
factor_correccion = 0.5  # factor de amplificación de ciertas contribuciones
perdida = 2           # unidades perdidas en el proceso
constante = 7         # constante experimental
# ====== NO MODIFICAR ESTE BLOQUE ======

# Código a analizar (comentado a propósito: NO lo descomente ni lo ejecute)
# eficiencia = reactivo_A + reactivo_B * factor_correccion / (reactivo_A + perdida - constante)
# print(eficiencia)

# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'tipo_de_error' identifica la excepción correcta", test_type="variable", variable_name="tipo_de_error",
                 validator=lambda v: isinstance(v, str) and v.strip().replace(' ', '').lower() == "zerodivisionerror",
                 success_message="'tipo_de_error' identifica correctamente ZeroDivisionError.",
                 error_message="'tipo_de_error' debería ser 'ZeroDivisionError'. Calcule a mano el denominador: reactivo_A + perdida - constante = 5 + 2 - 7 = 0, y dividir entre 0 genera esa excepción."),
        TestCase(name="Se explica el error", test_type="variable", variable_name="explicacion",
                 validator=lambda v: isinstance(v, str) and len(v.strip()) >= 15,
                 success_message="Se incluyó una explicación del error.",
                 error_message="'explicacion' debe ser un texto explicando por qué ocurre el error (mencione el denominador que se vuelve 0)."),
    ]),
    TestSection("Sección 2 — Estilo de código", [
        TestCase(name="No se ejecuta la línea con la división por cero", test_type="not_regex", pattern=r"^\s*eficiencia\s*=\s*reactivo_A",
                 success_message="La línea de la fórmula original permanece comentada, tal como se pidió.",
                 error_message="Se detectó que la línea original 'eficiencia = reactivo_A + ...' fue descomentada. El ejercicio pide analizar el error SIN ejecutar esa línea."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
reactivo_A = 5
reactivo_B = 10
factor_correccion = 0.5
perdida = 2
constante = 7

# eficiencia = reactivo_A + reactivo_B * factor_correccion / (reactivo_A + perdida - constante)
# El denominador es (reactivo_A + perdida - constante) = (5 + 2 - 7) = 0.
# Dividir entre ese denominador produce una excepción, sin necesidad de ejecutar el código.

tipo_de_error = "ZeroDivisionError"
explicacion = (
    "El denominador (reactivo_A + perdida - constante) = 5 + 2 - 7 = 0. "
    "Dividir entre 0 genera una excepción ZeroDivisionError en tiempo de ejecución."
)

# %% [markdown]
# **Ejercicio 5.2 - Plan de Pruebas de Código**
#
# Imagine que tiene que revisar el siguiente código de un compañero:
#
# ```python
# radio = 5
# PI = 3.14159
# area = PI * radio * radio
# print(f"El área del círculo es: {area}")
# ```
#
# Escriba un breve plan sobre cómo lo probaría para asegurar que es robusto y que no contiene errores lógicos (piense en casos normales, casos de borde y casos de error). Guarde su plan como texto en una variable llamada `plan_de_pruebas`.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Piense en distintos tipos de casos de prueba: normales, de borde (por ejemplo radio = 0) y de error (por ejemplo un radio negativo).
# - Considere también probar con valores decimales para el radio.
# - No necesita escribir código de prueba real, solo describir el plan como texto.
# - Guarde su plan como una cadena de texto en la variable `plan_de_pruebas`.
#
# </details>

# %%
# ====== CÓDIGO A ANALIZAR (NO MODIFICAR) ======
radio = 5
PI = 3.14159
area = PI * radio * radio
print(f"El área del círculo es: {area}")
# ====== FIN DEL CÓDIGO A ANALIZAR ======

# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="'plan_de_pruebas' es un plan con suficiente detalle", test_type="variable", variable_name="plan_de_pruebas",
                 validator=lambda v: isinstance(v, str) and len(v.strip()) >= 80,
                 success_message="'plan_de_pruebas' tiene suficiente contenido. Recuerde que esta prueba no evalúa la calidad de su razonamiento, solo que haya un plan desarrollado.",
                 error_message="'plan_de_pruebas' es demasiado corto o no es texto. Desarrolle un poco más su plan (al menos unas cuantas oraciones)."),
        TestCase(name="El plan menciona casos de borde o error", test_type="variable", variable_name="plan_de_pruebas",
                 validator=lambda v: isinstance(v, str) and any(p in v.lower() for p in ["borde", "límite", "limite", "negativo", "cero", "error", "inválid", "invalid"]),
                 success_message="El plan menciona casos de borde o de error, tal como se sugiere.",
                 error_message="El plan no parece mencionar casos de borde ni de error (por ejemplo: radio = 0, radio negativo, o radio con un tipo de dato inválido). Esta prueba no evalúa qué tan correcto es su razonamiento, solo que haya considerado ese tipo de casos."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
radio = 5
PI = 3.14159
area = PI * radio * radio
print(f"El área del círculo es: {area}")

plan_de_pruebas = (
    "1. Caso normal: probar con un radio típico (por ejemplo 5) y verificar que el área "
    "impresa coincida con PI * radio ** 2 calculado a mano.\n"
    "2. Caso de borde: probar con radio = 0, donde el área esperada es 0.\n"
    "3. Caso de error: probar con un radio negativo (por ejemplo -5), ya que un radio no "
    "debería ser negativo; decidir si el programa debe rechazar ese valor o convertirlo con abs().\n"
    "4. Caso de tipo de dato: probar con un radio decimal (por ejemplo 2.5) para confirmar "
    "que el cálculo también funciona con flotantes.\n"
    "5. Verificar el valor de PI usado: comparar contra math.pi para confirmar que la "
    "constante tiene suficiente precisión para el uso esperado."
)

# %% [markdown]
# ---
#
# ### 📋 Instrucciones para resolver
#
# 1. Lea el enunciado de cada ejercicio.
# 2. Escriba su solución en la celda de código correspondiente.
# 3. Ejecute la celda de pruebas automáticas para verificar su solución.
# 4. Si alguna prueba falla, lea el mensaje de error y corrija su código.
# 5. Puede consultar la celda de "Posible solución" si desea ver una referencia, pero intente resolver el ejercicio por su cuenta primero.
