# %% [markdown]
# # Principios de Informática: Subrutinas 🧩
# ### Construyendo programas modulares y reutilizables
#
# **Curso:** Principios de Informática
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/ci0202/blob/main/book/7_subrutinas/subrutinas.ipynb)
#
# ---
#
# ## 🗺️ Objetivos y contenidos
#
# Este notebook es una guía interactiva para comprender la importancia de la modularización y la reutilización en la programación, definir y utilizar subrutinas (funciones) en Python, identificar los componentes de una función y su firma, diferenciar entre funciones que retornan valores y funciones que no retornan (None), invocar funciones y pasar argumentos (mutables e inmutables).
#
# > "Cada subrutina es una pequeña herramienta para construir programas más grandes y con menos esfuerzo"
#
# **Importancia:**
# - La modularización facilita el desarrollo, mantenimiento y reutilización del código.
# - Las funciones permiten dividir problemas complejos en partes más simples y manejables.
# - Comprender el paso de argumentos y el retorno de valores es esencial para escribir programas robustos.
#
# **Contenidos:**
# 1. Modularización y reutilización
# 2. Definición y componentes de una función
# 3. Retorno de valores y el valor especial None
# 4. Invocación y paso de argumentos
# 5. Diferencias entre objetos mutables e inmutables

# %% [markdown]
# ---
#
# ## 1. La importancia de la Modularización y la Reutilización
#
# ---
#
# ### ¿Por Qué Dividir Para Conquistar? 💡
#
# Imagine que un mecánico está construyendo un auto. No construiría todo el auto como una sola pieza gigante y monolítica. Lo construiría en partes: el motor, el chasis, las ruedas, el sistema eléctrico. Cada parte es un **módulo** que se puede diseñar, construir y probar de forma independiente. Si el motor falla, se puede arreglar o reemplazar el motor sin tener que reconstruir todo el auto.
#
# En programación, se hace exactamente lo mismo. En lugar de escribir un programa muy largo y complejo como un solo bloque de código, se divide en piezas más pequeñas y manejables llamadas **subrutinas** (o, como se conocen más comúnmente en Python, **funciones**).
#
# ---

# %% [markdown]
# ### Modularización
#
# Dividir un problema complejo en subproblemas más simples. Esto hace que el código sea más fácil de leer, entender y depurar. 🧩
#
# Por ejemplo:
#
# ---

# %%
# --- Módulo de entrada de datos ---
def obtener_datos_estudiante():
    nombre = input("Ingresa el nombre del estudiante: ")
    nota = float(input(f"Ingrese la nota de {nombre}: "))
    return nombre, nota

# --- Módulo de lógica de evaluación ---
def evaluar_aprobacion(nota):
    return nota >= 6.0

# --- Módulo de salida ---
def mostrar_resultado(nombre, nota):
    if evaluar_aprobacion(nota):
        print(f"{nombre} ha aprobado con {nota}")
    else:
        print(f"{nombre} ha reprobado con {nota}")

# --- Función principal ---
for _ in range(3):
    nombre, nota = obtener_datos_estudiante()
    mostrar_resultado(nombre, nota)

# %% [markdown]
# ### Reutilización
#
# Una vez que se escribe una subrutina para una tarea específica (como calcular un promedio o validar un correo electrónico), se puede **llamarla** y usarla tantas veces como se ocupe, en diferentes partes del programa o incluso en otros programas ♻️.
#
# ---

# %% [markdown]
# Por ejemplo, si se tienen 3 números en 3 variables, y se solicita encontrar si estos 3 números son primos, se puede hacer lo siguiente:

# %%
numero_1 = 29
es_primo_1 = True

# Hallar si es primo
if numero_1 <= 1:
    es_primo_1 = False
else:
    for i in range(2, numero_1):
        if numero_1 % i == 0:
            es_primo_1 = False

numero_2 = 15
es_primo_2 = True

# Hallar si es primo
if numero_2 <= 1:
    es_primo_2 = False
else:
    for i in range(2, numero_2):
        if numero_2 % i == 0:
            es_primo_2 = False

numero_3 = 13
es_primo_3 = True

# Hallar si es primo
if numero_3 <= 1:
    es_primo_3 = False
else:
    for i in range(2, numero_3):
        if numero_3 % i == 0:
            es_primo_3 = False

print(f"El número {numero_1} es primo? {es_primo_1}")
print(f"El número {numero_2} es primo? {es_primo_2}")
print(f"El número {numero_3} es primo? {es_primo_3}")

# %% [markdown]
# En vez de repetir el código cada vez que se ocupa, se puede **modularizar**. Esto es, hacer el código reutilizable, poniéndolo en una función que se pueda usar varias veces.

# %%
def es_primo(numero):
    if numero <= 1:
        return False
    
    for i in range(2, numero):
        if numero % i == 0:
            return False
    
    return True

numero_1 = 29
es_primo_1 = es_primo(numero_1)

numero_2 = 15
es_primo_2 = es_primo(numero_2)

numero_3 = 13
es_primo_3 = es_primo(numero_3)

print(f"El número {numero_1} es primo? {es_primo_1}")
print(f"El número {numero_2} es primo? {es_primo_2}")
print(f"El número {numero_3} es primo? {es_primo_3}")

# %% [markdown]
# ---
#
# ## 2. Definición de subrutinas y sus componentes
#
# ---
#
# Una **subrutina** o **función** es un bloque de código organizado y reutilizable que realiza una única acción definida por el programador. Las funciones proporcionan una mejor modularidad para la aplicación y un alto grado de reutilización de código.
#
# **Ejemplo**:
# ```python
# def funcion(parametro: tipo) -> tipo:
#     [código]
#     ...
#     [código]
#     return [valor(es)]
# ```
# ---

# %% [markdown]
# ### Componentes de una Función en Python
#
# Una función se define con la palabra clave `def` y tiene los siguientes componentes:
#
# ```python
# def nombre_de_la_funcion(parametro: tipo_de_entrada) -> tipo_de_retorno:
#     """
#     Descripción
#     """
#
#     # Cuerpo de la función
#     [código]
#     ...
#     [código]
#     return [valor(es)]
# ```
#
# 1.  **`def`**: La palabra clave que le dice a Python: "¡Voy a definir una función!".
# 2.  **`nombre_de_la_funcion`**: Un nombre descriptivo (usando `snake_case`). Generalmente, se usan **verbos en infinitvo**, pues las funciones representan acciones. Por ejemplo: **comer,calcular_promedio, almacenar_valor**, etc.
# 3.  **`parametros`**: (Opcionales) Las variables que la función recibe como entrada para trabajar. Son como los ingredientes de una receta.
# 4.  **`tipo_de_entrada`**: (Opcional) El tipo de dato de un parámetro de la función.
# 5.  **`-> tipo_de_retorno`**: (Opcional pero muy recomendado) Una "type hint" que indica qué tipo de dato devolverá la función. Si no devuelve nada, se usa `-> None`.
# 6.  **`:`**: Dos puntos que marcan el inicio del bloque de la función.
# 7.  **`descripción`**: Es un comentario en donde se describe lo que hace una función, sus parámetros y su retorno.
# 8.  **Cuerpo de la función**: El bloque de código indentado que realiza la tarea.
# 9.  **`return`**: (Opcional) La palabra clave que envía un resultado de vuelta a quien llamó la función.
#
# ---

# %%
def sumar(a: int, b: int) -> int:
    """
    Esta función recibe dos números enteros y retorna su suma.
    """
    return a + b

# %% [markdown]
# #### Firma de la función
#
# La definición del nombre de la función, parámetros, tipos de entrada y tipos de retorno, se le llama la **firma** de la función.
#
# ```python
# def saludar(nombre: str) -> None:
#     ...
# ```
#
# ---

# %% [markdown]
# #### Invocación de funciones
#
# Se le llama **invocar** o **llamar** a la acción de ejecutar la función ya definida, con ciertos **argumentos**.
#
# > Un argumento es lo mismo que un parámetro, con al diferencia de que el argumento tiene un valor almacenado, y no es solo para definir la función.
#
# - **Parámetro**: es la variable que se define en la función para recibir un valor. Es como un “espacio vacío” que la función espera llenar.
# - **Argumento**: es el valor real que se pasa a la función cuando se le llama.
#
# ---

# %%
argumento_a = 10
argumento_b = 5

resultado = sumar(argumento_a, argumento_b)
print(resultado)

# %% [markdown]
# #### Docstring
#
# Un **docstring** es una cadena de texto (usualmente entre triple comillas `"""`) que se coloca justo después de la definición de una función. Sirve para documentar qué hace la función, describir sus parámetros y su valor de retorno.
#
# - Es la forma estándar de documentar funciones en Python.
# - Se puede acceder al docstring usando `help(nombre_funcion)` o `nombre_funcion.__doc__`.
#
# ---

# %%
def sumar(a: int, b: int) -> int:
    """
    Esta función recibe dos números enteros y retorna su suma.
    """
    return a + b

help(sumar)
print(sumar.__doc__)

# %% [markdown]
# **Estándar de Google para docstrings**:
# Google propone un formato claro y estructurado para los docstrings, que facilita la lectura y el análisis automático de la documentación. Este formato incluye secciones como Args, Returns y Raises.
#
# **Ejemplo (estilo Google):**
# ```python
# def sumar(a: int, b: int) -> int:
#     """Suma dos números enteros y devuelve el resultado.
#
#     Args:
#         a (int): Primer sumando.
#         b (int): Segundo sumando.
#
#     Returns:
#         int: La suma de a y b.
#     """
#     return a + b
# ```
#
# Las secciones más comunes en el estándar de Google son:
# - `Args:` para describir los parámetros de entrada.
# - `Returns:` para describir el valor de retorno.
# - `Raises:` para indicar posibles excepciones que puede lanzar la función.
#
# ---

# %% [markdown]
# #### El punto de entrada: la función `main()`
#
# A partir de este punto, todos los programas y ejercicios del curso se organizarán alrededor de una función especial llamada `main()`. Esta función actúa como el **punto de entrada** del programa: es la función de más alto nivel, la que orquesta las llamadas a las demás funciones (siguiendo el enfoque de arriba hacia abajo), y la primera en ejecutarse cuando el programa corre.
#
# Por convención:
# - `main()` no recibe parámetros y no retorna ningún valor (`-> None`).
# - Al final del archivo, después de definir todas las funciones, se agrega una llamada a `main()` para iniciar la ejecución del programa:
#
# ```python
# main()
# ```
#
# - En la práctica, este patrón deja muy claro, con solo mirar el final del archivo, dónde comienza la ejecución del programa.
#
# ---

# %%
def saludar(nombre: str) -> None:
    """Saluda a una persona por su nombre.

    Args:
        nombre (str): El nombre de la persona a saludar.

    Returns:
        None: No devuelve ningún valor.
    """
    print(f"¡Hola, {nombre}!")


def main() -> None:
    """Función principal: punto de entrada del programa."""
    saludar("Ana")
    saludar("Carlos")


main()

# %% [markdown]
# De aquí en adelante, **se espera que toda solución a los ejercicios de este curso incluya una función `main()`** que sirva como punto de entrada del programa, junto con una llamada a `main()` al final del archivo.
#
# ---

# %% [markdown]
# #### 🥇 Ejercicio: La primera función
#
# Defina una función llamada `saludar` que reciba un `nombre` como parámetro y muestre un saludo personalizado.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def saludar(nombre: str) -> None:
    """Esta función recibe un nombre e imprime un saludo en la consola.

    Args:
        nombre (str): El nombre de la persona a saludar.

    Returns:
        None: No devuelve ningún valor.
    """
    mensaje: str = f"¡Hola, {nombre}! Bienvenido a las funciones en Python."
    print(mensaje)

# %%
def main() -> None:
    """Función principal: punto de entrada del programa."""
    saludar("Ana")
    saludar("Carlos")


main()

# %% [markdown]
# #### Nombres de las funciones
#
# Es importante elegir nombres descriptivos y claros para las funciones. Por convención en Python, los nombres de las funciones deben escribirse en minúsculas y con palabras separadas por guiones bajos (`snake_case`).
#
# Además, es recomendable que el nombre de la función comience con un **verbo en infinitivo** que indique la acción que realiza, para que sea fácil entender su propósito.
#
# **Ejemplos de buenos nombres de funciones:**
# - `calcular_area`
# - `imprimir_resultado`
# - `obtener_datos`
# - `validar_email`
#
# Evite nombres genéricos o poco descriptivos como `funcion1`, `hacer_algo` o `proceso`. Un buen nombre ayuda a que el código sea más legible y mantenible.

# %% [markdown]
# ---
#
# ## 3. Retorno de valores
#
# ---
#
# No todas las funciones simplemente imprimen algo. Muchas veces, se ocupa que una función **calcule un valor** y lo entregue para que se pueda usar después. Para esto se utiliza la instrucción `return`.
#
# Cuando Python encuentra un `return`, sale inmediatamente de la función y devuelve el valor especificado.
#
# ```python
# def nombre_de_la_funcion(parametro: tipo_de_entrada) -> tipo_de_retorno:
#     # Cuerpo de la función
#     [variable] = [valor]
#     ... # Cálculos
#     return [variable]
# ```

# %% [markdown]
# #### ➕ Ejercicio: Sumadora
#
# Escriba un programa que pida dos números enteros y escriba la suma de todos los enteros desde el primer número hasta el segundo.
#
# Asegúrese de que su función está correcta usando `assert`.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def sumar_numeros_entre_a_y_b(a: int, b: int) -> int:
    """Suma todos los números entre a y b (incluidos).

    Args:
        a (int): El primer número.
        b (int): El segundo número.

    Returns:
        int: La suma de todos los números entre a y b (incluidos).
    """
    if a > b:
        a, b = b, a
    
    suma = 0
    for i in range(a, b + 1):
        suma += i
    return suma

# %%
def main() -> None:
    """Función principal: punto de entrada del programa."""
    suma1 = sumar_numeros_entre_a_y_b(1, 9)
    print(f"La suma de los números entre 1 y 9 es: {suma1}")


main()

# %%
assert sumar_numeros_entre_a_y_b(1, 9) == 45, "Error en la suma de números entre 1 y 9"

# %%
assert sumar_numeros_entre_a_y_b(20, 8) == 108, "Error en la suma de números entre 20 y 8"

# %% [markdown]
# ### El valor especial `None` en Python
#
# En Python, `None` es un valor especial que representa la ausencia de un valor o un valor nulo. Es equivalente a "nada" o "sin resultado".
#
# - Cuando una función **no tiene una instrucción `return`**, o tiene un `return` sin valor, **devuelve automáticamente `None`**.
# - Se utiliza para indicar que una variable aún no tiene un valor útil, o que una función no retorna nada.
#
# ---

# %%
def saludar_sin_retorno() -> None:
    """Esta función no retorna ningún valor, solo imprime un mensaje."""
    print("Hola")

# %%
resultado = saludar_sin_retorno()
print(resultado)  # Imprime: None

# %%
def saludar_sin_retorno() -> None:
    """Esta función no retorna ningún valor, solo imprime un mensaje."""
    print("Hola")
    return

# %%
resultado = saludar_sin_retorno()
print(resultado)  # Imprime: None

# %% [markdown]
# En este ejemplo, la función imprime un mensaje, pero no retorna ningún valor, por lo que la variable `resultado` contiene `None`.

# %% [markdown]
# #### 🎰 Ejercicio: Máximo común divisor
#
# El máximo común divisor (mcd) de dos números enteros positivos es el número entero más grande que divide uniformemente en ambos. Por ejemplo, el máximo común divisor de 102 y 68 es 34, ya que ambos 102 y 68 son múltiplos de 34, además no hay entero mayor que 34 y divida uniformemente en 102 y 68. El mcd de 8 y 15 es 1. El mcd de 8 y 16 es 8. El mcd de 50 y 8 es 2.
#
# Escriba un programa que pida al usuario **dos valores** y calcula el máximo común divisor de estos
# dos valores. Puede suponer que ambos valores son digitados correctamente, como enteros
# positivos. Luego de devolver el valor del mcd, el programa pregunta al usuario si desea calcular
# el mcd de otros dos valores ("¿Desea calcular otro mcd? O digite 'N' o 'n' para salir ").
#
# Haga una función llamada `calcular_mcd` que reciba dos números y retorne el mcd.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def calcular_mcd(numero_1: int, numero_2: int) -> int:
    """Calcula el máximo común divisor (MCD) de dos números enteros.

    Args:
        numero_1 (int): El primer número.
        numero_2 (int): El segundo número.

    Returns:
        int: El MCD de los dos números.
    """
    # Determinar el mínimo de los dos números
    if numero_1 < numero_2:
        minimo = numero_1
    else:
        minimo = numero_2

    mcd = 1  # Inicializar el MCD como 1
    for numero in range(minimo + 1):
        if numero_1 % numero == 0 and numero_2 % numero == 0:
            mcd = numero
        
    return mcd

# %%
def main() -> None:
    """Función principal: punto de entrada del programa.

    Pide al usuario dos valores, calcula su MCD, y le pregunta
    si desea calcular el MCD de otro par de valores.
    """
    continuar = True
    while continuar:
        numero_1 = int(input("Ingrese el primer valor: "))
        numero_2 = int(input("Ingrese el segundo valor: "))

        mcd = calcular_mcd(numero_1, numero_2)
        print(f"El MCD de {numero_1} y {numero_2} es: {mcd}")

        respuesta = input("¿Desea calcular otro mcd? O digite 'N' o 'n' para salir ")
        continuar = respuesta.lower() != "n"


main()

# %% [markdown]
# ---
#
# ## 4. Invocación y paso de argumentos
#
# ---
#
# * **Invocación**: Es el acto de "llamar" o ejecutar una función. Se hace escribiendo el nombre de la función seguido de paréntesis `()`.
# * **Argumentos**: Son los valores reales que se le envían a la función cuando se invoca. Estos valores se asignan a los **parámetros** definidos en la función.
#
# ```python
# def calcular(parametro_1: tipo, parametro_2: tipo_2) -> tipo_de_retorno:
#     ...
#
# # Invocamos la función
# calcular(argumento_1, argumento_2)
# ```
# ---

# %%
def imprimir_parametros(parametro_1: int, parametro_2: str) -> None:
    """Esta función recibe dos parámetros y los imprime en la consola.

    Args:
        parametro_1 (int): Un número entero.
        parametro_2 (str): Una cadena de texto.
    
    Returns:
        None: No devuelve ningún valor.
    """
    print(f"Parámetro 1: {parametro_1}, Parámetro 2: {parametro_2}")

# %%
# Invocación de la función
argumento_1 = 42
argumento_2 = "Hola Mundo"
imprimir_parametros(argumento_1, argumento_2)

# %%
# Invocación de la función
imprimir_parametros(42, "Hola Mundo")

# %% [markdown]
# Se puede hacer explícito a cuáles parámetros nos referimos cuando llamamos a la función. Python asigna a los parámetros los argumentos según el orden en el que vengan.

# %%
def sumar(a: int, b: int) -> int:
    """
    Esta función recibe dos números enteros y retorna su suma.
    """
    print(f"Argumento a {a}. Argumento b {b}")
    return a + b

argumento_a = 10
argumento_b = 5

# Especificamos los argumentos por nombre
resultado = sumar(a=argumento_a, b=argumento_b)
print(resultado)

# %% [markdown]
# **NOTA**: En Python, los tipos de datos indicados en los parámetros son solo guías visuales (anotaciones de tipo).
#
# > No son restrictivos. Por ejemplo, si un parámetro se indica como `int` pero se pasa un `str` como argumento, Python no genera un error automáticamente, sino que intentará ejecutar la función con el valor proporcionado, lo que **puede causar errores en tiempo de ejecución si el tipo no es compatible o errores lógicos**.

# %%
def multiplicar_caracter(c: str, n: int) -> str:
    """Esta función retorna el carácter 'c' multiplicado 'n' veces.

    Args:
        c (str): El carácter a multiplicar.
        n (int): El número de veces que se multiplicará el carácter.

    Returns:
        str: El carácter 'c' multiplicado 'n' veces.
    """
    return c * n

# %%
resultado = multiplicar_caracter("a", 5)
print(resultado)  # Imprime: aaaaa

# %%
# Intercambiamos los argumentos
resultado = multiplicar_caracter(3, 'b')
print(resultado)

# %% [markdown]
# No obstante, si ponemos los nombres de los parámetros, podemos pasarlos en distinto orden manteniendo la lógica.

# %%
# Intercambiamos los argumentos
resultado = multiplicar_caracter(n=3, c='b')
print(resultado)

# %% [markdown]
# ### Localidad 🏟️ vs Globalidad 🌎
#
# Cuando se trabaja con funciones en programación, es importante entender la diferencia entre variables **locales** y **globales**:
#
# - **🏟️ Variables locales:** Son aquellas que se definen dentro de una función y solo existen mientras la función se está ejecutando. No pueden ser accedidas fuera de la función.
#
# - **🌎 Variables globales:** Son aquellas que se definen fuera de cualquier función y pueden ser accedidas desde cualquier parte del programa, incluyendo dentro de las funciones (aunque no es recomendable modificarlas directamente dentro de una función).
#
# ---

# %%
x = 20 # Variable globa;

def mi_funcion():
    x = 10  # Variable local
    print(f"X de la función: {x}")

print(f"X antes de la función: {x}.")  # Imprime 20

mi_funcion()  # Imprime 10

print(f"X después de la función: {x}.")  # Imprime 20

# %% [markdown]
# En este ejemplo, la variable `x` dentro de la función es **local** y diferente de la variable `x` global.

# %% [markdown]
# Si se quiere modificar una variable global en una función, se debe usar la palabra clave `global` de la siguiente forma:

# %%
x = 20
def modificar_global() -> None:
    global x
    x += 20

# %% [markdown]
# ### ¿Funciones como variables?
#
# En Python las funciones son **objetos de primera clase** (“first-class objects”).
# Eso significa que, igual que números, cadenas o listas, **se pueden asignar a variables**, pasar como argumento a otra función o devolver como resultado de una función.
#
# Almacenar una función en una variable es como darle un "alias", con el nombre de la variable.
#
# ---

# %%
def saludar(nombre: str) -> str:
    """
    Esta función recibe un nombre y devuelve un saludo.

    Args:
        nombre (str): El nombre de la persona a saludar.

    Returns:
        str: Un saludo personalizado.
    """
    return f"Hola, {nombre}!"


mi_funcion = saludar # OJO: NO se ponen paréntesis, porque no se está invocando la función. SOLO se está asignando la función a otra variable.

print(type(mi_funcion))  # Imprime: <class 'function'>
print(mi_funcion("Ana"))  # Imprime: Hola, Ana!

# %% [markdown]
# #### ½ Ejercicio: Partidas
#
# Suponga ocupa procesar la siguiente función por partes para su curso de Cálculo 1:
#
# $$
# f(x) =
# \begin{cases}
# x^2 + 1 & \text{si } x < -1 \\[2mm]
# \frac{1}{x} & \text{si } -1 \le x < 0 \\[1mm]
# \sqrt{x} & \text{si } 0 \le x \le 4 \\[1mm]
# x & \text{si } x > 4
# \end{cases}
# $$
#
# Haga una función en python que modele el problema.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
# Definimos cada función
def f1(x: float) -> float:
    return x**2 + 1

def f2(x: float) -> float:
    return 1/x

def f3(x: float) -> float:
    return x**0.5

def f4(x: float) -> float:
    return x

# Función por partes
def f(x: float) -> float:
    """
    Procesa el valor de x según la función por partes definida:  
    f(x) =  
        x^2 + 1   si x < -1  
        1/x       si -1 <= x < 0  
        x**0.5    si 0 <= x <= 4  
        x         si x > 4  

    Args:
        x (float): El valor de entrada.

    Returns:
        float: El valor procesado según la función por partes.
    """
    funcion = None
    if x < -1:
        funcion = f1
    elif -1 <= x < 0:
        funcion = f2
    elif 0 <= x <= 4:
        funcion = f3
    else:  # x > 4
        funcion = f4

    return funcion(x)

# %%
def main() -> None:
    """Función principal: punto de entrada del programa."""
    x = 3
    print(f(x))

    x = -2
    print(f(x))

    x = 5
    print(f(x))

    x = -0.5
    print(f(x))


main()

# %% [markdown]
# ---
#
# ## 5. Diferencias entre objetos mutables e inmutables en el paso de argumentos
#
# ---
#
# Este es un concepto **crucial**. La forma en que Python pasa los argumentos a las funciones tiene un efecto diferente dependiendo de si el tipo de dato es **inmutable** o **mutable**.
#
# ---

# %% [markdown]
# ### Paso de Tipos Inmutables (como `int`, `str`, `float`, `bool`)
#
# Cuando se pasa un objeto inmutable a una función como argumento, la función recibe una **copia del valor**. Si se modifica el parámetro dentro de la función, la variable original fuera de la función **NO cambia**.
#
# ---

# %%
def intentar_modificar_numero(numero: int) -> None:
    """Esta función intenta modificar el valor de un número, pero no afecta al número original fuera de la función.

    Args:
        numero (int): Un número entero que se intenta modificar.

    Returns:
        None: No devuelve ningún valor.
    """
    print(f"    Dentro de la función (antes): {numero}")
    numero = 100 # Se crea una nueva variable 'numero' local a la función
    print(f"    Dentro de la función (después): {numero}")

# %%
# Variable original
mi_numero = 10
print(f"Fuera de la función (antes): {mi_numero}")

intentar_modificar_numero(mi_numero)

print(f"Fuera de la función (después): {mi_numero}") # ¡No cambió!

# %% [markdown]
# ### Paso de Tipos Mutables (como `list`, `dict`)
#
# Cuando se pasa un objeto mutable a una función, la función recibe una **referencia al objeto original**. Si se modifica el objeto dentro de la función (por ejemplo, agregando un elemento a una lista), el objeto original fuera de la función **SÍ cambia**.
#
# ---

# %%
def agregar_elemento_a_lista(una_lista: list) -> None:
    """Esta función agrega un elemento a una lista, modificando el objeto original.

    Args:
        una_lista (list): La lista a la que se le agregará un elemento.

    Returns:
        None: No devuelve ningún valor.
    """
    print(f"    Dentro de la función (antes): {una_lista}")
    una_lista.append(99) # Se modifica el objeto original
    print(f"    Dentro de la función (después): {una_lista}")

# %%
# Lista original
mi_lista = [1, 2, 3]
print(f"Fuera de la función (antes): {mi_lista}")

agregar_elemento_a_lista(mi_lista)

print(f"Fuera de la función (después): {mi_lista}") # ¡Sí cambió!

# %% [markdown]
# La mutabilidad funciona con **referencias**. En Python, **las variables no son cajas que guardan valores directamente**, sino que son **referencias a objetos** en memoria.
#
# ```python
# def modificar_lista(lista_parametro: list) -> list:
#     """
#     Modifica una lista
#
#     Args:
#         lista (list): lista a modificar
#
#     Returns:
#         list: Lista modificada
#     """
#     lista_parametro.append(100)    # MUTACIÓN: agrega al mismo objeto
#     return lista_parametro
#
# lista_argumento = [1, 2, 3]
# resultado = modificar_lista(lista_argumento)
# ```
#
#
# > Al hacer `lista_argumento = [1, 2, 3]`, antes de llamar a la función:
#
# `lista_argumento` ──► [1, 2, 3]
#
# > Al llamar a la función:
#
# `lista_argumento` ──► [1, 2, 3] ◄── `lista_parametro`
#
# **OJO:** Las variables solo funcionan como punteros a ubicaciones de los valores en memoria. NO están ligadas a los valores como tal.
#
# ---

# %% [markdown]
# #### 🕵️‍♀️ Ejercicio: Detective
#
# Un profesor quiere escribir una función que “reinicie” cualquier estructura de datos y la convierta en vacía, pero tiene un error lógico, puesto que no conoce bien del concepto de `mutabilidad`. ¿Cuál es el error?
#
# ---

# %%
def reiniciar(valor: list) -> None:
    """
    Acá debe ir un docstring que explique la función. PENDIENTE. Att. El prof. del ejercicio.
    """
    valor = valor[:0]

# Pruebas
lista = [1, 2, 3]
texto = "hola"

print(reiniciar(lista))
print(lista)

# %% [markdown]
# Por eso, lo importante es distinguir entre:
#
# - **Reasignar**: cambiar a qué objeto apunta una variable.
# - **Mutar**: modificar el contenido de un objeto en el lugar.

# %% [markdown]
# ---
#
# ## 6. Funciones integradas en python
#
# Python ya tiene algunas funciones integradas dentro de su intérprete, como lo son `input` y `print`. Puede revisar la [Documentación oficial de Python](https://docs.python.org/es/3.13/library/functions.html) para ver la lista completa de funciones ya integradas.
#
# ---

# %% [markdown]
# ### `sorted`
#
# La función sorted en Python toma un iterable (como una lista, una tupla o una cadena) y devuelve una nueva lista con todos los elementos ordenados.
#
# ---

# %%
sorted([3, 1, 2])        # Devuelve [1, 2, 3]
sorted("cba")             # Devuelve ['a', 'b', 'c']
sorted([3, 1, 2], reverse=True)  # Devuelve [3, 2, 1]

# %% [markdown]
# ### `abs`
#
# La función `abs` en Python devuelve el valor absoluto de un número, es decir, la distancia de ese número al cero sin importar si es positivo o negativo.
#
# ---

# %%
# Ejemplo de uso de abs
print(abs(-10))   # 10

# %% [markdown]
# ### `divmod`
#
# La función `divmod` en Python toma dos números y devuelve una tupla con el cociente y el residuo de la división entera.
#
# **Parámetros:**
#
# - `a`: el dividendo (número que se va a dividir).
# - `b`: el divisor (número por el cual se divide).
#
# **Valor devuelto:**
# Una tupla `(cociente, residuo)` donde:
# - `cociente` es el resultado de la división entera (`a // b`).
# - `residuo` es el resto de la división (`a % b`).
#
# ---

# %%
# Ejemplo de uso de divmod
print(divmod(10, 3))  # (3, 1) -> 10 // 3 = 3 y 10 % 3 = 1

# %% [markdown]
# ### `pow`
#
# La función `pow` en Python devuelve el resultado de elevar un número a una potencia. También puede recibir un tercer parámetro para calcular el módulo del resultado.
#
# **Parámetros:**
#
# - `x`: la base.
# - `y`: el exponente al que se va a elevar la base.
#
# ---

# %%
# Ejemplo de uso de pow
print(pow(2, 3))  # 8 -> 2 elevado a la 3

# %% [markdown]
# ### `min`
#
# La función `min` en Python devuelve el **valor mínimo** de un iterable o entre dos o más argumentos.
#
# ---

# %%
# Ejemplo de uso de min
print(min(2, 3))  # 2
print(min([3, 1, 2]))  # 1

# %% [markdown]
# ### `max`
#
# La función `max` en Python devuelve el **valor máximo** de un iterable o entre dos o más argumentos.
#
# ---

# %%
# Ejemplo de uso de max
print(max(2, 3))  # 3
print(max([3, 1, 2]))  # 3

# %% [markdown]
# ### `sum`
#
# La función `sum` en Python **devuelve la suma de todos los elementos de un iterable**, como listas o tuplas, y permite opcionalmente sumar un valor inicial.
#
# **Parámetros:**
#
# - `iterable`: un objeto como lista, tupla o conjunto cuyos elementos se van a sumar.
# - `start` (opcional): un valor inicial que se suma al total. Por defecto es 0.
#
# ---

# %%
print(sum([1, 2, 3, 4]))        # Devuelve 10
print(sum([1, 2, 3, 4], 5))     # Devuelve 15 (5 + 1 + 2 + 3 + 4)

# %% [markdown]
# ### `round`
#
# La función `round` en Python **redondea un número al entero más cercano o a un número de decimales especificado**.
#
# **Parámetros:**
#
# - `number`: el número que se quiere redondear.
# - `ndigits` (opcional): la cantidad de decimales a la que se desea redondear. Por defecto es 0 (redondeo a entero).
#
# ---

# %%
# Ejemplo de uso de round
print(round(2.5))  # 3
print(round(2.5123, 1))  # 2.5

# %% [markdown]
# ## Ejercicios adicionales
#
# ---

# %% [markdown]
# **1. Convertidor de Temperatura**
#
# Escribe una función `convertir_celsius_a_fahrenheit` que reciba una temperatura en Celsius y devuelva el valor equivalente en Fahrenheit. La fórmula es: `F = C * 9/5 + 32`.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def convertir_celsius_a_fahrenheit(celsius: float) -> float:
    """Convierte una temperatura de Celsius a Fahrenheit.

    Args:
        celsius (float): La temperatura en grados Celsius.

    Returns:
        float: La temperatura convertida a grados Fahrenheit.
    """
    fahrenheit = celsius * 9/5 + 32
    return fahrenheit


def main() -> None:
    """Función principal: punto de entrada del programa."""
    temp_c = 25.0
    temp_f = convertir_celsius_a_fahrenheit(temp_c)
    print(f"{temp_c}°C es equivalente a {temp_f}°F")


main()

# %% [markdown]
# **2. Encontrar el Máximo**
#
# Crea una función `encontrar_maximo` que reciba dos números y devuelva el mayor de los dos, sin usar la función `max()` de Python.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def encontrar_maximo(num1: float, num2: float) -> float:
    """Encuentra el valor máximo entre dos números.

    Args:
        num1 (float): El primer número.
        num2 (float): El segundo número.

    Returns:
        float: El número mayor entre los dos.
    """
    if num1 > num2:
        return num1
    else:
        return num2


def main() -> None:
    """Función principal: punto de entrada del programa."""
    print(f"El máximo entre 10 y 25 es: {encontrar_maximo(10, 25)}")
    print(f"El máximo entre -5 y -1 es: {encontrar_maximo(-5, -1)}")


main()

# %% [markdown]
# **3. Longitud de una Cadena**
#
# Escriba una función `calcular_longitud` que reciba una cadena de texto y devuelva el número de caracteres que contiene, sin usar la función `len()` de Python. (Pista: use un bucle `for`).
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def calcular_longitud(texto: str) -> int:
    """Calcula la longitud de una cadena de texto.

    Args:
        texto (str): La cadena de texto cuya longitud se desea calcular.

    Returns:
        int: La longitud de la cadena de texto.
    """
    contador = 0
    for _ in texto:
        contador += 1
    return contador


def main() -> None:
    """Función principal: punto de entrada del programa."""
    print(f"La longitud de 'Python' es: {calcular_longitud('Python')}")
    print(f"La longitud de '' es: {calcular_longitud('')}")


main()

# %% [markdown]
# **4. Composición de funciones**
#
# Haga dos funciones:
# - `doblar(x)`: que reciba un número y devuelva el doble.
# - `sumar_cinco(x)`: que reciba un número y le sume 5.
#
# Luego, escriba una función que use ambas funciones para calcular el doble de un número y luego sumarle 5 (por ejemplo, para el número 4, el resultado debe ser 13).
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def doblar(x: float) -> float:
    """Devuelve el doble de un número.

    Args:
        x (float): El número a duplicar.

    Returns:
        float: El doble del número.
    """
    return x * 2

def sumar_cinco(x: float) -> float:
    """Suma 5 a un número.

    Args:
        x (float): El número al que se le sumará 5.

    Returns:
        float: El número incrementado en 5.
    """
    return x + 5

def usar_ambas_funciones(numero: float) -> float:
    """Calcula el doble de un número y luego le suma 5.

    Args:
        numero (float): El número a procesar.

    Returns:
        float: El resultado del cálculo.
    """
    resultado_doblar = doblar(numero)
    resultado_final = sumar_cinco(resultado_doblar)
    return resultado_final


def main() -> None:
    """Función principal: punto de entrada del programa."""
    print(f"El resultado para 4 es: {usar_ambas_funciones(4)}")


main()

# %% [markdown]
# **5. Tablas extendidas**
#
#
# Escriba una función en Python que:
#
# 1. Reciba un número `n` (entero positivo).
# 2. Imprima la **tabla de multiplicar del 1 al 10** para cada número que exista del 1 al `n` de manera ordenada.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
def imprimir_tablas_extendidas(n: int) -> None:
    """
    Imprime las tablas de multiplicar del 1 al 10 para un número dado.

    Args:
        n (int): El número para el cual se imprimirán las tablas de multiplicar.

    Returns:
        None
    """
    for numero in range(1, n + 1):
        print(f"Tabla de multiplicar del {numero}:")
        for i in range(1, 11):
            print(f"{numero} x {i} = {numero * i}")

        print()


def main() -> None:
    """Función principal: punto de entrada del programa."""
    imprimir_tablas_extendidas(3)


main()

# %% [markdown]
# ## 🎯 Resumen y Ejercicios de Repaso
#
# Se presentó una síntesis de subrutinas en Python.
#
# ### 📚 Contenidos revisados
#
# 1. **Modularización y reutilización**:
#    - Cómo dividir problemas complejos en partes más simples usando funciones.
#    - Reutilizar código para evitar repeticiones y facilitar el mantenimiento.
#
# 2. **Definición y componentes de una función**:
#    - Sintaxis básica de una función en Python.
#    - Firma de la función, parámetros, tipo de retorno y docstrings.
#
# 3. **Retorno de valores y el valor especial `None`**:
#    - Diferencia entre funciones que retornan valores y las que no.
#    - Uso y significado de `None` en Python.
#
# 4. **Invocación y paso de argumentos**:
#    - Cómo llamar funciones y pasar argumentos (mutables e inmutables).
#    - Efectos de modificar argumentos dentro de una función.
#
# 5. **Ejercicios prácticos**:
#    - Aplicación de funciones para resolver problemas comunes: conversión de temperaturas, encontrar el máximo, calcular la longitud de una cadena, modificar listas, etc.
#
# ---

# %% [markdown]
# ## 📝 Ejercicios de Práctica
#
# A continuación se proponen ejercicios organizados por tema para consolidar los conceptos.
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución (cuando el ejercicio lo amerite).

# %% [markdown]
# ### Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade --force-reinstall notebook-cell-tester --q

# %% [markdown]
# -----
#
# ### 1️⃣ **Ejercicios: Funciones**

# %% [markdown]
# **Ejercicio 1.1 — Máximo**
#
# Defina una función `max_de_tres()`, que tome tres números como argumentos y devuelva el mayor de ellos. No puede usar la función `max` que Python tiene por defecto.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use una variable, por ejemplo `mayor`, inicializada con el primer argumento, y actualícela comparando contra los otros dos con sentencias `if`
# - Por ejemplo: `if b > mayor: mayor = b`, y algo similar para `c`
# - No se le permite usar la función `max()` incorporada de Python
# - Recuerde organizar su solución con una función `main()` y llamarla al final del programa
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="El mayor está en la primera posición", test_type="return",
                 function_name="max_de_tres", inputs=[9, 2, 5], expected=9,
                 success_message="max_de_tres(9, 2, 5) devuelve correctamente 9.",
                 error_message="max_de_tres(9, 2, 5) no devuelve 9. Revise que esté comparando los tres argumentos correctamente."),
        TestCase(name="El mayor está en la segunda posición", test_type="return",
                 function_name="max_de_tres", inputs=[2, 9, 5], expected=9,
                 success_message="max_de_tres(2, 9, 5) devuelve correctamente 9.",
                 error_message="max_de_tres(2, 9, 5) no devuelve 9. Revise que esté comparando los tres argumentos correctamente."),
        TestCase(name="El mayor está en la tercera posición", test_type="return",
                 function_name="max_de_tres", inputs=[2, 5, 9], expected=9,
                 success_message="max_de_tres(2, 5, 9) devuelve correctamente 9.",
                 error_message="max_de_tres(2, 5, 9) no devuelve 9. Revise que esté comparando los tres argumentos correctamente."),
        TestCase(name="Funciona con números negativos", test_type="return",
                 function_name="max_de_tres", inputs=[-1, -5, -3], expected=-1,
                 success_message="max_de_tres(-1, -5, -3) devuelve correctamente -1.",
                 error_message="max_de_tres(-1, -5, -3) no devuelve -1. Recuerde que -1 es mayor que -3 y -5."),
    ]),
    TestSection("Sección 2 — Casos límite", [
        TestCase(name="Los tres números son iguales", test_type="return",
                 function_name="max_de_tres", inputs=[4, 4, 4], expected=4,
                 success_message="max_de_tres(4, 4, 4) devuelve correctamente 4.",
                 error_message="max_de_tres(4, 4, 4) no devuelve 4. Cuando los tres valores son iguales, cualquiera de ellos es el resultado correcto."),
        TestCase(name="Funciona con números decimales", test_type="return",
                 function_name="max_de_tres", inputs=[1.5, 2.7, 2.2], expected=2.7,
                 success_message="max_de_tres(1.5, 2.7, 2.2) devuelve correctamente 2.7.",
                 error_message="max_de_tres(1.5, 2.7, 2.2) no devuelve 2.7. Revise su lógica de comparación con valores decimales."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="No se usa la función max() de Python", test_type="not_regex",
                 pattern=r"\bmax\(",
                 success_message="No se usó la función max() de Python.",
                 error_message="El enunciado prohíbe usar la función max() incorporada en Python. Implemente la comparación usted mismo con condicionales."),
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def max_de_tres(a: float, b: float, c: float) -> float:
    """Determina el mayor de tres números sin usar la función max incorporada de Python.

    Args:
        a (float): El primer número.
        b (float): El segundo número.
        c (float): El tercer número.

    Returns:
        float: El mayor de los tres números.
    """
    mayor = a
    if b > mayor:
        mayor = b
    if c > mayor:
        mayor = c
    return mayor


def main() -> None:
    """Función principal: punto de entrada del programa."""
    print(max_de_tres(3, 7, 5))
    print(max_de_tres(-1, -5, -3))


main()

# %% [markdown]
# **Ejercicio 1.2 — Día de la semana**
#
# Existen múltiples formas de determinar el día de la semana correspondiente a cualquier fecha. En este ejercicio utilizaremos un método descrito por Claus Tøndering, que permite obtener el día de la semana para fechas posteriores al año 1582.
#
# El procedimiento consiste en realizar una serie de cálculos intermedios basados en el año, el mes y el día de la fecha:
#
# 1. A es el cociente de la división de 14 menos el mes entre 12,
# 2. B es el año menos A
# 3. C es el mes más doce veces A menos 2
# 4. D es el cociente de la división de B entre 4
# 5. E es el cociente de la división de B entre 100
# 6. F es el cociente de la división de B entre 400
# 7. G es el cociente de 31 veces C entre 12
# 8. H es el día más B más D menos E más F más G
# 9. I es el resto de la división de H entre 7
#
# Si I es 0, el día cae en Domingo; si I es 1, el día cae en Lunes; si I es 2, el día cae en Martes, etc.
#
# Haga una función que aplique este algoritmo, pidiendo como parámetro el día del mes, el número de mes, y el año.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Siga los pasos del algoritmo en el orden indicado, guardando cada resultado intermedio (A, B, C, ..., H, I) en una variable distinta
# - Use el operador de división entera `//` para calcular los cocientes, y el operador módulo `%` para calcular el resto
# - El valor de I corresponde justamente al resto de dividir H entre 7
# - Puede usar una lista con los nombres de los días para traducir el índice (0=domingo, 1=lunes, ..., 6=sábado) a un nombre legible
# - Pida el día, el mes y el año con `input()` dentro de `main()`, conviértalos con `int()` antes de pasarlos a su función
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="1 de enero de 2024 es lunes (índice 1)", test_type="return",
                 function_name="obtener_indice_dia_semana", inputs=[1, 1, 2024], expected=1,
                 success_message="Calcula correctamente que el 1 de enero de 2024 es lunes.",
                 error_message="obtener_indice_dia_semana(1, 1, 2024) debería devolver 1 (lunes). Revise que aplicó cada paso del algoritmo de Tøndering en el orden correcto (A, B, C, D, E, F, G, H, I)."),
        TestCase(name="1 de enero de 2000 es sábado (índice 6)", test_type="return",
                 function_name="obtener_indice_dia_semana", inputs=[1, 1, 2000], expected=6,
                 success_message="Calcula correctamente que el 1 de enero de 2000 es sábado.",
                 error_message="obtener_indice_dia_semana(1, 1, 2000) debería devolver 6 (sábado). Revise los cálculos de D, E y F, que dependen de divisiones enteras entre 4, 100 y 400."),
        TestCase(name="31 de diciembre de 1999 es viernes (índice 5)", test_type="return",
                 function_name="obtener_indice_dia_semana", inputs=[31, 12, 1999], expected=5,
                 success_message="Calcula correctamente que el 31 de diciembre de 1999 es viernes.",
                 error_message="obtener_indice_dia_semana(31, 12, 1999) debería devolver 5 (viernes). Revise el cálculo de A: es el cociente de (14 - mes) entre 12."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def obtener_indice_dia_semana(dia: int, mes: int, anio: int) -> int:
    """Calcula el índice del día de la semana usando el método de Tøndering.

    Args:
        dia (int): El día del mes.
        mes (int): El número de mes (1-12).
        anio (int): El año (posterior a 1582).

    Returns:
        int: El índice del día de la semana: 0=domingo, 1=lunes, 2=martes,
            3=miércoles, 4=jueves, 5=viernes, 6=sábado.
    """
    a = (14 - mes) // 12
    b = anio - a
    c = mes + 12 * a - 2
    d = b // 4
    e = b // 100
    f = b // 400
    g = (31 * c) // 12
    h = dia + b + d - e + f + g
    return h % 7


def main() -> None:
    """Función principal: punto de entrada del programa."""
    nombres_dias = ["domingo", "lunes", "martes", "miércoles", "jueves", "viernes", "sábado"]
    dia = int(input("Día del mes: "))
    mes = int(input("Número de mes: "))
    anio = int(input("Año: "))
    indice = obtener_indice_dia_semana(dia, mes, anio)
    print(f"Esa fecha cae en {nombres_dias[indice]}.")


main()

# %% [markdown]
# **Ejercicio 1.3 — Área**
#
# Escriba una función que pida la anchura y altura de un rectángulo y lo dibuje con caracteres producto (`*`):
#
# ```
# Anchura del rectángulo: 5
# Altura del rectángulo: 3
# * * * * *
# * * * * *
# * * * * *
# ```
#
# Pista: Usa 2 ciclos.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use un ciclo `for` externo que se repita `altura` veces, uno por cada fila del rectángulo
# - Dentro de ese ciclo, use otro `for` interno que se repita `anchura` veces para ir construyendo el contenido de esa fila
# - Puede ir concatenando `"* "` a una cadena en cada iteración del ciclo interno, y luego imprimir esa cadena
# - Use `.strip()` sobre la fila antes de imprimirla, para quitar el espacio sobrante al final
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Anchura 5, altura 3: se dibujan 3 filas de 5 asteriscos", test_type="regex_output",
                 stdin_input="5\n3\n",
                 pattern=r"(?:\* \* \* \* \*\n){2}\* \* \* \* \*",
                 success_message="Dibuja correctamente el rectángulo de anchura 5 y altura 3.",
                 error_message="El rectángulo no tiene la forma correcta para anchura 5 y altura 3. Debe imprimir 3 filas, cada una con 5 asteriscos separados por un espacio.",
                 description="Ejemplo del enunciado."),
        TestCase(name="Anchura 4, altura 2: se dibujan 2 filas de 4 asteriscos", test_type="regex_output",
                 stdin_input="4\n2\n",
                 pattern=r"\* \* \* \*\n\* \* \* \*",
                 success_message="Dibuja correctamente el rectángulo de anchura 4 y altura 2.",
                 error_message="El rectángulo no tiene la forma correcta para anchura 4 y altura 2. Debe imprimir 2 filas, cada una con 4 asteriscos."),
    ]),
    TestSection("Sección 2 — Casos límite", [
        TestCase(name="Anchura 1, altura 1: se dibuja un único asterisco", test_type="regex_output",
                 stdin_input="1\n1\n",
                 pattern=r"^\*$",
                 success_message="Maneja correctamente el caso de anchura y altura 1.",
                 error_message="Con anchura 1 y altura 1, la salida debe ser una sola línea con un único asterisco."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
        TestCase(name="Se usan ciclos para construir el rectángulo", test_type="regex",
                 pattern=r"\bfor\b[\s\S]*\bfor\b",
                 success_message="Se usaron 2 ciclos, tal como sugiere la pista del enunciado.",
                 error_message="La pista del enunciado sugiere usar 2 ciclos (uno para las filas y otro para las columnas). No se detectaron dos ciclos `for` en el código."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def dibujar_rectangulo(anchura: int, altura: int) -> None:
    """Dibuja un rectángulo de asteriscos separados por espacios.

    Args:
        anchura (int): La cantidad de asteriscos por fila.
        altura (int): La cantidad de filas del rectángulo.

    Returns:
        None: No devuelve ningún valor.
    """
    for _ in range(altura):
        fila = ""
        for _ in range(anchura):
            fila += "* "
        print(fila.strip())


def main() -> None:
    """Función principal: punto de entrada del programa."""
    anchura = int(input("Anchura del rectángulo: "))
    altura = int(input("Altura del rectángulo: "))
    dibujar_rectangulo(anchura, altura)


main()

# %% [markdown]
# **Ejercicio 1.4 — Área avanzada**
#
# Repita el ejercicio anterior, pero logre hacer lo mismo con un solo ciclo. Por último, hágalo sin ciclos.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Para la versión de un solo ciclo: construya la fila completa antes del ciclo con algo como `("* " * anchura).strip()`, y luego use un único `for` que solo controle cuántas veces se imprime esa fila ya armada
# - Para la versión sin ciclos: recuerde que multiplicar una lista por un entero la repite, por ejemplo `[fila] * altura` genera una lista con `altura` copias de `fila`
# - Use `"\n".join(...)` para unir esa lista de filas en una sola cadena y hacer un único `print()`
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="dibujar_rectangulo_un_ciclo: anchura 5, altura 3", test_type="output",
                 function_name="dibujar_rectangulo_un_ciclo", inputs=[5, 3],
                 expected="* * * * *\n* * * * *\n* * * * *",
                 success_message="dibujar_rectangulo_un_ciclo(5, 3) imprime correctamente el rectángulo.",
                 error_message="dibujar_rectangulo_un_ciclo(5, 3) no imprime el rectángulo esperado (3 filas de 5 asteriscos)."),
        TestCase(name="dibujar_rectangulo_sin_ciclos: anchura 5, altura 3", test_type="output",
                 function_name="dibujar_rectangulo_sin_ciclos", inputs=[5, 3],
                 expected="* * * * *\n* * * * *\n* * * * *",
                 success_message="dibujar_rectangulo_sin_ciclos(5, 3) imprime correctamente el rectángulo.",
                 error_message="dibujar_rectangulo_sin_ciclos(5, 3) no imprime el rectángulo esperado (3 filas de 5 asteriscos)."),
        TestCase(name="dibujar_rectangulo_sin_ciclos: anchura 4, altura 2", test_type="output",
                 function_name="dibujar_rectangulo_sin_ciclos", inputs=[4, 2],
                 expected="* * * *\n* * * *",
                 success_message="dibujar_rectangulo_sin_ciclos(4, 2) imprime correctamente el rectángulo.",
                 error_message="dibujar_rectangulo_sin_ciclos(4, 2) no imprime el rectángulo esperado (2 filas de 4 asteriscos)."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
        TestCase(name="dibujar_rectangulo_un_ciclo usa un ciclo", test_type="regex",
                 pattern=r"def\s+dibujar_rectangulo_un_ciclo\b(?:(?!\ndef\s)[\s\S])*\b(?:for|while)\b",
                 success_message="dibujar_rectangulo_un_ciclo usa un ciclo para dibujar el rectángulo.",
                 error_message="dibujar_rectangulo_un_ciclo debe usar un ciclo (for o while) para imprimir cada fila del rectángulo."),
        TestCase(name="dibujar_rectangulo_sin_ciclos no usa ningún ciclo", test_type="not_regex",
                 pattern=r"def\s+dibujar_rectangulo_sin_ciclos\b(?:(?!\ndef\s)[\s\S])*\b(?:for|while)\b",
                 success_message="dibujar_rectangulo_sin_ciclos no usa ningún ciclo, tal como pide el enunciado.",
                 error_message="dibujar_rectangulo_sin_ciclos no debe usar ningún ciclo (ni for ni while). Piense en cómo construir todas las filas usando operaciones sobre cadenas o listas (por ejemplo, multiplicando una lista por un entero)."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def dibujar_rectangulo_un_ciclo(anchura: int, altura: int) -> None:
    """Dibuja un rectángulo de asteriscos usando un único ciclo.

    Args:
        anchura (int): La cantidad de asteriscos por fila.
        altura (int): La cantidad de filas del rectángulo.

    Returns:
        None: No devuelve ningún valor.
    """
    fila = ("* " * anchura).strip()
    for _ in range(altura):
        print(fila)


def dibujar_rectangulo_sin_ciclos(anchura: int, altura: int) -> None:
    """Dibuja un rectángulo de asteriscos sin usar ningún ciclo.

    Args:
        anchura (int): La cantidad de asteriscos por fila.
        altura (int): La cantidad de filas del rectángulo.

    Returns:
        None: No devuelve ningún valor.
    """
    fila = ("* " * anchura).strip()
    print("\n".join([fila] * altura))


def main() -> None:
    """Función principal: punto de entrada del programa."""
    anchura = int(input("Anchura del rectángulo: "))
    altura = int(input("Altura del rectángulo: "))
    dibujar_rectangulo_un_ciclo(anchura, altura)
    print()
    dibujar_rectangulo_sin_ciclos(anchura, altura)


main()

# %% [markdown]
# **Ejercicio 1.5 — Predicción**
#
# Sin ejecutar el siguiente programa, determine cuál es la salida en pantalla si se ingresan los valores x=6, y=7.
#
# Antes de correr la celda de código, escriba su predicción como comentario. Luego ejecute la celda para verificarla.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - No ejecute el código antes de anotar su predicción como comentario
# - Recuerde que los parámetros de una función (`x`, `y` dentro de `coordenadaZ`) son variables locales: reasignarlos dentro de la función no modifica las variables externas que tengan el mismo nombre
# - El docstring dentro de la función es solo documentación; no tiene ningún efecto sobre la ejecución del programa
# - Fíjese con cuidado en qué instrucciones están dentro del ciclo `for` pero fuera de la función `coordenadaZ`, ya que solo esas son las que realmente modifican `x` y `y` del programa principal en cada iteración
#
# </details>

# %%
# Su código acá: antes de ejecutar, escriba como comentario su predicción
# de lo que imprimirá el programa para x=6, y=7.
# Mi predicción: ...

def coordenadaZ(x: int, y: int) -> int:
    """
    Este es un docstring.
    """
    x = x + 10
    y = y + 15
    return x + y


# Programa principal
x = int(input("Coordenada eje x: "))
y = int(input("Coordenada eje y: "))
for i in range(3):
    z = coordenadaZ(x, y)
    x = x + 1
    y = y + 1
print(x, " . ", y)

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Para x=6, y=7 el programa imprime 9  .  10", test_type="regex_output",
                 stdin_input="6\n7\n",
                 pattern=r"9\s*\.\s*10",
                 success_message="El programa (sin modificar) imprime 9  .  10 para x=6, y=7, tal como se predijo con el análisis de parámetros inmutables.",
                 error_message="No modifique la lógica del programa dado, solo agregue su predicción como comentario. Con x=6, y=7 el programa debe imprimir '9  .  10' (x=9, y=10)."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
# Mi predicción: coordenadaZ no modifica x ni y fuera de la función, porque
# numero/x/y son parámetros locales (tipos inmutables): reasignarlos dentro
# de la función no afecta a las variables originales. El ciclo se ejecuta
# 3 veces y, en cada iteración, solo x = x + 1 y y = y + 1 (fuera de la
# función) afectan a las variables externas. Por lo tanto, al terminar el
# ciclo: x = 6 + 3 = 9, y = 7 + 3 = 10. La salida es: 9  .  10

def coordenadaZ(x: int, y: int) -> int:
    """
    Este es un docstring.
    """
    x = x + 10
    y = y + 15
    return x + y


# Programa principal
x = int(input("Coordenada eje x: "))
y = int(input("Coordenada eje y: "))
for i in range(3):
    z = coordenadaZ(x, y)
    x = x + 1
    y = y + 1
print(x, " . ", y)

# %% [markdown]
# **Ejercicio 1.6 — Corrección**
#
# El siguiente programa debería imprimir el número 2 si se le ingresan como valores x=5, y=1 pero en su lugar imprime 5. ¿Qué hay que corregir?
#
# Corrija el error directamente en el código de la siguiente celda.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Compare, dentro de cada función, los nombres de los parámetros declarados (`a`, `b`) contra los nombres de variable que realmente se usan en el cuerpo (`x`, `y`)
# - Python permite que una función lea variables globales cuando no existe un parámetro local con ese nombre; eso puede hacer que el código "funcione" pero usando los valores equivocados
# - La corrección consiste en hacer que el cuerpo de cada función use los mismos nombres que fueron declarados como parámetros
#
# </details>

# %%
def maximo(a, b):
  if x > y:
    return x
  else:
    return y


def minimo(a, b):
  if x < y:
    return x
  else:
    return y


# Programa principal
x = int(input("Un número: "))
y = int(input("Otro número: "))
print(maximo(x - 3, minimo(x + 2, y - 5)))

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Con x=5, y=1 el programa imprime 2", test_type="regex_output",
                 stdin_input="5\n1\n",
                 pattern=r"^2$",
                 success_message="Con x=5, y=1 el programa imprime correctamente 2.",
                 error_message="El error es que maximo y minimo usan las variables globales x, y en vez de sus propios parámetros a, b. Corrija el cuerpo de ambas funciones para que comparen a y b."),
    ]),
    TestSection("Sección 6 — Funciones", [
        TestCase(name="maximo(3, 7) devuelve 7", test_type="return",
                 function_name="maximo", inputs=[3, 7], expected=7,
                 success_message="maximo(3, 7) devuelve correctamente 7.",
                 error_message="maximo(3, 7) no devuelve 7. Revise que la función compare sus propios parámetros a y b, y no variables externas."),
        TestCase(name="maximo(-2, -5) devuelve -2", test_type="return",
                 function_name="maximo", inputs=[-2, -5], expected=-2,
                 success_message="maximo(-2, -5) devuelve correctamente -2.",
                 error_message="maximo(-2, -5) no devuelve -2. Revise que la función compare sus propios parámetros a y b, y no variables externas."),
        TestCase(name="minimo(3, 7) devuelve 3", test_type="return",
                 function_name="minimo", inputs=[3, 7], expected=3,
                 success_message="minimo(3, 7) devuelve correctamente 3.",
                 error_message="minimo(3, 7) no devuelve 3. Revise que la función compare sus propios parámetros a y b, y no variables externas."),
        TestCase(name="minimo(-2, -5) devuelve -5", test_type="return",
                 function_name="minimo", inputs=[-2, -5], expected=-5,
                 success_message="minimo(-2, -5) devuelve correctamente -5.",
                 error_message="minimo(-2, -5) no devuelve -5. Revise que la función compare sus propios parámetros a y b, y no variables externas."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def maximo(a, b):
    if a > b:
        return a
    else:
        return b


def minimo(a, b):
    if a < b:
        return a
    else:
        return b


# Programa principal
x = int(input("Un número: "))
y = int(input("Otro número: "))
print(maximo(x - 3, minimo(x + 2, y - 5)))

# %% [markdown]
# **Ejercicio 1.7 — Ocurrencias**
#
# Solicite al usuario un número entero y luego un único dígito. Cree una función que informe la cantidad de ocurrencias del dígito en el número. Póngale al nombre de la función `frecuencia`.
#
# Por ejemplo: Si el número es 467807, y el dígito es 7, la función debería retornar el número 2.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Convierta el número a una cadena de texto con `str(numero)` para poder recorrer sus dígitos uno por uno
# - Use un ciclo `for` para recorrer cada carácter de esa cadena y compárelo con `digito` usando `==`
# - Lleve un contador que inicie en 0 y se incremente cada vez que encuentre una coincidencia
# - Nombre la función `frecuencia`, tal como lo pide el enunciado, y recuerde envolver la lectura de datos en una función `main()`
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Ejemplo del enunciado: frecuencia(467807, '7') == 2", test_type="return",
                 function_name="frecuencia", inputs=[467807, "7"], expected=2,
                 success_message="frecuencia(467807, '7') devuelve correctamente 2.",
                 error_message="frecuencia(467807, '7') no devuelve 2. Recuerde recorrer cada dígito del número (por ejemplo, convirtiéndolo a texto con str()) y comparar con el dígito buscado."),
        TestCase(name="El dígito aparece varias veces seguidas: frecuencia(1111, '1') == 4", test_type="return",
                 function_name="frecuencia", inputs=[1111, "1"], expected=4,
                 success_message="frecuencia(1111, '1') devuelve correctamente 4.",
                 error_message="frecuencia(1111, '1') no devuelve 4. Revise que el contador se incremente cada vez que encuentra el dígito, no solo una vez."),
    ]),
    TestSection("Sección 2 — Casos límite", [
        TestCase(name="El dígito no aparece: frecuencia(120, '5') == 0", test_type="return",
                 function_name="frecuencia", inputs=[120, "5"], expected=0,
                 success_message="frecuencia(120, '5') devuelve correctamente 0.",
                 error_message="frecuencia(120, '5') no devuelve 0. Si el dígito no aparece en el número, el resultado debe ser 0."),
        TestCase(name="Número igual a 0: frecuencia(0, '0') == 1", test_type="return",
                 function_name="frecuencia", inputs=[0, "0"], expected=1,
                 success_message="frecuencia(0, '0') devuelve correctamente 1.",
                 error_message="frecuencia(0, '0') no devuelve 1. El número 0 tiene un único dígito, '0'."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def frecuencia(numero: int, digito: str) -> int:
    """Cuenta cuántas veces aparece un dígito dentro de un número entero.

    Args:
        numero (int): El número entero en el que se buscará el dígito.
        digito (str): El dígito a buscar, como un carácter de un solo dígito.

    Returns:
        int: La cantidad de veces que el dígito aparece en el número.
    """
    contador = 0
    for caracter in str(numero):
        if caracter == digito:
            contador += 1
    return contador


def main() -> None:
    """Función principal: punto de entrada del programa."""
    numero = int(input("Ingrese un número entero: "))
    digito = input("Ingrese un único dígito: ")
    print(frecuencia(numero, digito))


main()

# %% [markdown]
# **Ejercicio 1.8 — Muchos ciclos**
#
# Observe con atención el siguiente código (ya se encuentra en la celda de código de abajo), que contiene dos funciones: `calcular_suma` y `calcular_suma_de_varias_sumas_de_numeros`.
#
# ¿Qué valor devuelve la función `calcular_suma_de_varias_sumas_de_numeros(5)`? No ejecute el código.
#
# - A) 35
# - B) 55
# - C) 5
# - D) 10
#
# Justifique su respuesta explicando qué ocurre en cada iteración del ciclo y cómo se actualiza la variable `suma`.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - No necesita ejecutar el código: analice cómo `calcular_suma_de_varias_sumas_de_numeros(5)` recorre `range(5)`, es decir, i = 0, 1, 2, 3, 4, y en cada paso suma `calcular_suma(i + 1)`
# - Calcule por separado el valor de `calcular_suma(1)`, `calcular_suma(2)`, `calcular_suma(3)`, `calcular_suma(4)` y `calcular_suma(5)` (cada una es la suma de los primeros n enteros), y luego súmelos todos
# - Guarde su respuesta como una cadena de un solo carácter ("A", "B", "C" o "D") en la variable `respuesta`, y su razonamiento como texto en la variable `justificacion`
#
# </details>

# %%
def calcular_suma(n: int) -> int:
    suma = 0
    for i in range(1, n + 1):
        suma += i
    return suma


def calcular_suma_de_varias_sumas_de_numeros(N: int) -> int:
    suma = 0
    for i in range(N):
        suma += calcular_suma(i + 1)

    return suma


# Su código acá: guarde la letra de su respuesta ("A", "B", "C" o "D") en la
# variable 'respuesta', y una breve justificación en la variable 'justificacion'.
respuesta = ""
justificacion = ""

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="La respuesta seleccionada es la A) 35", test_type="variable",
                 variable_name="respuesta",
                 validator=lambda v: isinstance(v, str) and v.strip().upper() == "A",
                 success_message="La respuesta es correcta: A) 35.",
                 error_message="'respuesta' no es 'A'. Calcule calcular_suma(1) + calcular_suma(2) + ... + calcular_suma(5) paso a paso: 1 + 3 + 6 + 10 + 15 = 35."),
        TestCase(name="Se incluye una justificación", test_type="variable",
                 variable_name="justificacion",
                 validator=lambda v: isinstance(v, str) and len(v.strip()) >= 20,
                 success_message="Se incluyó una justificación de la respuesta.",
                 error_message="'justificacion' está vacía o es muy corta. Explique qué calcula calcular_suma(i + 1) en cada iteración del ciclo de calcular_suma_de_varias_sumas_de_numeros."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def calcular_suma(n: int) -> int:
    suma = 0
    for i in range(1, n + 1):
        suma += i
    return suma


def calcular_suma_de_varias_sumas_de_numeros(N: int) -> int:
    suma = 0
    for i in range(N):
        suma += calcular_suma(i + 1)

    return suma


respuesta = "A"
justificacion = (
    "calcular_suma_de_varias_sumas_de_numeros(5) suma calcular_suma(i + 1) "
    "para i = 0..4, es decir calcular_suma(1) + calcular_suma(2) + calcular_suma(3) "
    "+ calcular_suma(4) + calcular_suma(5) = 1 + 3 + 6 + 10 + 15 = 35."
)

# %% [markdown]
# -----
#
# ### 2️⃣ **Ejercicios: Pruebas de caja negra**

# %% [markdown]
# **Ejercicio 2.1 — Probando el máximo**
#
# Use la función que creó en el ejercicio 1.2 para hacer pruebas de caja negra. Compruebe si su programa está comportándose bien en meses como febrero, que no tiene 30 días. Use la instrucción `assert`.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Recuerde que una prueba de caja negra no revisa el código interno de la función; solo comprueba que la salida sea razonable para una entrada dada
# - Pruebe la función con una fecha que no existe en el calendario, como el 30 de febrero (`dia=30, mes=2`), y observe si la función detecta o no el problema
# - Use `assert` para verificar, por ejemplo, que el índice devuelto siga estando en el rango válido (entre 0 y 6) incluso con esa fecha inválida
#
# </details>

# %%
def obtener_indice_dia_semana(dia: int, mes: int, anio: int) -> int:
    """Calcula el índice del día de la semana usando el método de Tøndering,
    tal como en el ejercicio 1.2.

    Args:
        dia (int): El día del mes.
        mes (int): El número de mes (1-12).
        anio (int): El año.

    Returns:
        int: El índice del día de la semana (0=domingo, ..., 6=sábado).
    """
    a = (14 - mes) // 12
    b = anio - a
    c = mes + 12 * a - 2
    d = b // 4
    e = b // 100
    f = b // 400
    g = (31 * c) // 12
    h = dia + b + d - e + f + g
    return h % 7


# Su código acá: agregue uno o más assert que prueben, con caja negra, el
# comportamiento de la función con una fecha inválida: el 30 de febrero
# (un mes que nunca tiene 30 días).

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 6 — Funciones", [
        TestCase(name="La función sigue funcionando correctamente para una fecha válida", test_type="return",
                 function_name="obtener_indice_dia_semana", inputs=[1, 1, 2024], expected=1,
                 success_message="obtener_indice_dia_semana(1, 1, 2024) sigue devolviendo 1 (lunes): no se modificó la función dada.",
                 error_message="obtener_indice_dia_semana(1, 1, 2024) ya no devuelve 1. No modifique la función dada; solo agregue asserts para probarla con una fecha inválida."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="Se usa la instrucción assert", test_type="regex",
                 pattern=r"\bassert\b",
                 success_message="Se usó la instrucción assert, tal como pide el enunciado.",
                 error_message="No se encontró la instrucción assert. El enunciado pide usar assert para hacer la prueba de caja negra."),
        TestCase(name="Se llama a la función con día=30 y mes=2 (30 de febrero)", test_type="regex",
                 pattern=r"obtener_indice_dia_semana\s*\(\s*30\s*,\s*2\b",
                 success_message="Se probó la función con el 30 de febrero, una fecha inválida.",
                 error_message="No se encontró una llamada a obtener_indice_dia_semana con día=30 y mes=2. Agregue una prueba de caja negra para esa fecha inválida (por ejemplo: obtener_indice_dia_semana(30, 2, 2024))."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def obtener_indice_dia_semana(dia: int, mes: int, anio: int) -> int:
    """Calcula el índice del día de la semana usando el método de Tøndering,
    tal como en el ejercicio 1.2.

    Args:
        dia (int): El día del mes.
        mes (int): El número de mes (1-12).
        anio (int): El año.

    Returns:
        int: El índice del día de la semana (0=domingo, ..., 6=sábado).
    """
    a = (14 - mes) // 12
    b = anio - a
    c = mes + 12 * a - 2
    d = b // 4
    e = b // 100
    f = b // 400
    g = (31 * c) // 12
    h = dia + b + d - e + f + g
    return h % 7


# Caja negra: el 30 de febrero no existe en ningún año, pero la función no
# valida los datos de entrada, así que igual calcula un índice "válido"
# (entre 0 y 6) sin lanzar ningún error. Esto revela que a la función le
# falta validar que el día sea coherente con el mes (y con si el año es
# bisiesto, en el caso de febrero).
indice = obtener_indice_dia_semana(30, 2, 2024)
assert 0 <= indice <= 6, "La función debería devolver un índice entre 0 y 6, incluso con una fecha inválida como el 30 de febrero."

# %% [markdown]
# **Ejercicio 2.2 — Pequeños errores**
#
# Analice la siguiente función (ya se encuentra en la celda de código de abajo, junto con varias pruebas `assert`). Contiene un error lógico que solo se manifiesta en un caso particular.
#
# A continuación de la función, se ejecutan varias pruebas `assert`. Una de ellas fallará debido al error en el código.
#
# 1. **Ejecute el código** para confirmar cuál de las pruebas falla.
# 2. **Identifique** la prueba `assert` que no se cumple.
# 3. **Explique** por qué esa prueba falla. ¿Cuál es el caso extremo que la función no maneja correctamente y cuál es el valor que debería retornar?
# 4. **Corrija la función** para que todas las pruebas pasen.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Ejecute primero la celda de código tal como está para ver cuál `assert` falla y qué mensaje de error se produce
# - Preste especial atención al caso límite `numero = 0`: según el enunciado, la función debe considerar positivo solo lo que sea estrictamente mayor que cero
# - Revise el operador de comparación usado dentro del `if`: compare `>=` contra `>` y piense cuál de los dos corresponde a "estrictamente mayor que cero"
#
# </details>

# %%
def validar_numero_positivo(numero):
    """
    Verifica si un número es estrictamente mayor que cero.

    >>> validar_numero_positivo(5)
    True
    >>> validar_numero_positivo(-1)
    False
    """
    if numero >= 0:
        return True
    else:
        return False


# A continuación, se ejecutan las siguientes pruebas para la función.
# Una de ellas fallará debido al error en el código.

assert validar_numero_positivo(5) == True
assert validar_numero_positivo(-3) == False
assert validar_numero_positivo(100) == True
assert validar_numero_positivo(0) == False

print("Todas las pruebas han pasado.")

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 6 — Funciones", [
        TestCase(name="validar_numero_positivo(5) es True", test_type="return",
                 function_name="validar_numero_positivo", inputs=[5], expected=True,
                 success_message="validar_numero_positivo(5) devuelve correctamente True.",
                 error_message="validar_numero_positivo(5) no devuelve True."),
        TestCase(name="validar_numero_positivo(-3) es False", test_type="return",
                 function_name="validar_numero_positivo", inputs=[-3], expected=False,
                 success_message="validar_numero_positivo(-3) devuelve correctamente False.",
                 error_message="validar_numero_positivo(-3) no devuelve False."),
        TestCase(name="validar_numero_positivo(100) es True", test_type="return",
                 function_name="validar_numero_positivo", inputs=[100], expected=True,
                 success_message="validar_numero_positivo(100) devuelve correctamente True.",
                 error_message="validar_numero_positivo(100) no devuelve True."),
        TestCase(name="Caso límite: validar_numero_positivo(0) es False", test_type="return",
                 function_name="validar_numero_positivo", inputs=[0], expected=False,
                 success_message="validar_numero_positivo(0) devuelve correctamente False: el error lógico fue corregido.",
                 error_message="validar_numero_positivo(0) debería devolver False, ya que la función verifica si el número es ESTRICTAMENTE mayor que cero. Revise el operador de comparación usado (>= vs >)."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def validar_numero_positivo(numero):
    """
    Verifica si un número es estrictamente mayor que cero.

    >>> validar_numero_positivo(5)
    True
    >>> validar_numero_positivo(-1)
    False
    """
    if numero > 0:
        return True
    else:
        return False


# La prueba que fallaba era assert validar_numero_positivo(0) == False:
# como la condición original era "numero >= 0", el 0 se consideraba
# positivo. Se corrigió cambiando la comparación a "numero > 0", ya que
# el 0 no es estrictamente mayor que cero.

assert validar_numero_positivo(5) == True
assert validar_numero_positivo(-3) == False
assert validar_numero_positivo(100) == True
assert validar_numero_positivo(0) == False

print("Todas las pruebas han pasado.")

# %% [markdown]
# -----
#
# ### 📋 **Instrucciones para resolver:**
#
# 1. Lea el enunciado de cada ejercicio.
# 2. Escriba su solución en la celda de código correspondiente.
# 3. Ejecute la celda de pruebas automáticas para verificar su solución.
# 4. Si alguna prueba falla, lea el mensaje de error y corrija su código.
# 5. Puede consultar la celda de "Posible solución" si desea ver una referencia, pero intente resolver el ejercicio por su cuenta primero.
