# %% [markdown]
# # Principios de Informática: Introducción al Uso de Bibliotecas 📚
# ### Ampliando los superpoderes con código preexistente
#
# **Curso:** Principios de Informática
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/EnriqueVilchezL/ci0202/blob/main/book/9_introduccion_al_uso_de_bibliotecas/introduccion_al_uso_de_bibliotecas.ipynb)
#
# ---
#
# ## 🗺️ Objetivos y contenidos
#
# Este notebook es una guía interactiva para comprender qué es una biblioteca y por qué son útiles en programación, importar y utilizar bibliotecas estándar de Python como `math`, `random` y `datetime`, consultar la documentación de una biblioteca y sus funciones, usar diferentes formas de importación (`import`, `from ... import`, `as`), aplicar funciones y métodos de bibliotecas en ejemplos prácticos.
#
# > "Detectar y corregir errores es una habilidad esencial para cualquier programador."
#
# **Importancia:**
# - Las bibliotecas permiten reutilizar código probado y eficiente.
# - Facilitan la resolución de problemas complejos con menos esfuerzo.
# - Amplían las capacidades de Python para tareas especializadas.
#
# **Contenidos:**
# 1. Concepto de bibliotecas
# 2. Exploración de documentación de bibliotecas
# 3. Importación de bibliotecas

# %% [markdown]
# ---
#
# ## 1. Concepto de bibliotecas
#
# ---
#
# ### ¿Qué es una Biblioteca? 🏛️
#
# Imagine que quiere construir un carro y, en lugar de fabricar cada tornillo, cada rueda y cada pieza del motor desde cero, va a una tienda de auto-repuestos y compra esas piezas ya hechas por expertos. Se ahorraría una cantidad increíble de tiempo y esfuerzo, y probablemente el resultado sería más fiable.
#
# En programación, una **biblioteca** (o *library*) es exactamente eso: una colección de código preescrito (funciones, clases, etc.) que podemos **importar** y usar en nuestros propios programas. Nos permite no tener que "reinventar la rueda".
#
# Python tiene una vasta **Biblioteca Estándar** que viene incluida por defecto, y un ecosistema gigantesco de bibliotecas de terceros (como NumPy, Pandas, Matplotlib) que podemos instalar para realizar tareas especializadas.
#
# La sintaxis para acceder a una biblioteca es:
#
# ```python
# import [nombre_de_biblioteca]
# ```
#
# ---

# %%
import numpy
import pandas
import matplotlib
import random
import math

# %% [markdown]
# ### ¿Por qué usar bibliotecas?
# * **Ahorro de Tiempo**: No se tiene que escribir código para tareas comunes.
# * **Fiabilidad**: El código de las bibliotecas populares ha sido probado por miles de desarrolladores.
# * **Rendimiento**: Muchas bibliotecas (especialmente las científicas) están altamente optimizadas.
# * **Nuevas Capacidades**: Dan acceso a funcionalidades que serían muy complejas de programar desde cero (ej. gráficos, machine learning, etc.).

# %% [markdown]
# ---
#
# ## 2. Exploración de documentación de bibliotecas
#
# ---
#
# Cada biblioteca tiene su propio "manual de usuario" llamado **documentación**. Aprender a leer la documentación es una de las habilidades más importantes de un programador.
#
# La documentación indica:
# * ¿Qué hace la biblioteca?
# * ¿Qué funciones y clases contiene?
# * ¿Cómo se usan esas funciones (qué parámetros aceptan y qué devuelven)?
# * Ejemplos de uso.
#
# La documentación oficial de Python es un excelente lugar para empezar: [docs.python.org](https://docs.python.org/3/)
#
# ---

# %% [markdown]
# #### 🧮 Ejercicio: Explorar la Biblioteca `math`
#
# 1.  Vaya a la documentación de la biblioteca `math` de Python: [link](https://docs.python.org/3/library/math.html).
# 2.  Busque cómo se llama la función para calcular la raíz cuadrada.
# 3.  Busque el valor de la constante matemática Pi (`π`).
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
# Después de explorar la documentación, se sabe que:
# - La función para la raíz cuadrada es sqrt()
# - La constante Pi es math.pi

# Para usarla, primero hay que importarla
import math


def main() -> None:
    """Función principal: punto de entrada del programa."""
    numero = 81
    raiz_cuadrada = math.sqrt(numero)
    pi_valor = math.pi

    print(f"La raíz cuadrada de {numero} es: {raiz_cuadrada}")
    print(f"El valor de Pi es aproximadamente: {pi_valor}")


main()

# %% [markdown]
# ### La función `help()`
#
# Si se quiere ver la documentación desde python se puede usar la función `help()`, que imprime la información de la biblioteca o función que se busca comprender.
#
# ---

# %%
import math
help(math)  # Muestra la documentación de la biblioteca math

# %%
help(math.sqrt)  # Muestra la documentación de la función sqrt

# %% [markdown]
# ### Cursor
#
# Algunos entornos de progamación permiten observar parte de la documentación de las funciones o bibliotecas poniendo el cursor sobre ellas.
#
# Por ejemplo, poniendo el cursor sobre `math` posiblemente se vea un mensaje como:
#
# ```python
# module: math
# This module provides access to the mathematical functions
# defined by the C standard.
# ```

# %% [markdown]
# ---
#
# ## 3. Importación de bibliotecas
#
# ---
#
# Para usar una biblioteca en el código, primero hay que **importarla**. Hay varias formas de hacerlo.
#
# ---

# %% [markdown]
# ### `import biblioteca`
#
# Esta es la forma más común para la mayoría de bibliotecas. Importa la biblioteca completa y, para usar sus funciones, hay usar el nombre de la biblioteca como prefijo.
#
# ---

# %%
import math

math.sqrt(25)  # Calcula la raíz cuadrada de 25

# %% [markdown]
# ### `from biblioteca import componente`
#
# Importa solo una función o componente específico de la biblioteca. Esto permite llamarla directamente sin el prefijo.
#
# ---

# %%
from math import sqrt

sqrt(25)  # Calcula la raíz cuadrada de 25 sin usar el prefijo math.

# %% [markdown]
# ### `import biblioteca as alias`
#
# A veces, los nombres de las bibliotecas son muy largos. Se les puede dar un "apodo" o **alias** para escribir menos.
#
# ---

# %%
import math as ma

ma.sqrt(25)  # Calcula la raíz cuadrada de 25 usando el alias ma

# %% [markdown]
# ### `from biblioteca import componente as alias_componente`
#
# A veces, los nombres de los objetos o funciones de las bibliotecas son muy largos. Se les puede dar un "apodo" o **alias** para escribir menos.
#
# ---

# %%
from math import sqrt as raiz

raiz(25)  # Calcula la raíz cuadrada de 25 usando el alias raiz

# %% [markdown]
# ### Ejemplos con Bibliotecas Comunes
#
# A continuación, se exploran tres bibliotecas muy útiles de la Biblioteca Estándar de Python.
#
# ---

# %% [markdown]
# **1. La Biblioteca `math`**
#
# Proporciona acceso a funciones matemáticas.
#
# ---

# %%
import math

# Funciones trigonométricas (trabajan en radianes)
angulo_rad = math.pi / 2 # 90 grados
print(f"Seno de 90°: {math.sin(angulo_rad)}")

# %%
# Factorial
print(f"Factorial de 5 (5!): {math.factorial(5)}")

# %%
# Potencias y logaritmos
print(f"2 elevado a la 10: {math.pow(2, 10)}")
print(f"Logaritmo natural de 10: {math.log(10)}")

# %% [markdown]
# #### 🥇 Ejercicio: Optimizando primos
#
# En ejercicios anteriores, se vio cómo utilizar ciclos para determinar si un número es primo. Ahora se va a optimizar ese proceso utilizando la biblioteca `math`.
#
# Enunciado:
# 1.	Solicite al usuario un número entero positivo n.
# 2.	Escriba un programa que determine si n es primo de manera eficiente.
# - En lugar de revisar todos los números hasta n-1, solo revise hasta la raíz cuadrada de n usando math.isqrt(n).
# 3.	El programa debe mostrar un mensaje indicando si el número es primo o no primo.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
import math

def es_primo(numero: int) -> bool:
    """
    Verifica si un número es primo.

    Args:
        numero (int): El número a verificar.

    Returns:
        bool: True si el número es primo, False en caso contrario.
    """
    if numero <= 1:
        return False

    for i in range(2, math.isqrt(numero) + 1):
        if numero % i == 0:
            return False

    return True


def main() -> None:
    """Función principal: punto de entrada del programa."""
    n = int(input("Ingrese un número para verificar si es primo: "))
    if es_primo(n):
        print(f"{n} es un número primo.")
    else:
        print(f"{n} no es un número primo.")


main()

# %% [markdown]
# **2. La Biblioteca `random`**
#
# Permite generar números pseudo-aleatorios y realizar selecciones al azar.
#
# ---

# %%
import random

# Generar un número entero aleatorio en un rango
dado = random.randint(1, 6)
print(f"Lanzamiento de un dado: {dado}")

# %%
# Elegir un elemento al azar de una lista
opciones = ["piedra", "papel", "tijera"]
eleccion_computadora = random.choice(opciones)
print(f"La computadora elige: {eleccion_computadora}")

# %%
# Barajar una lista
cartas = ["As", "Rey", "Reina", "Jota"]
random.shuffle(cartas)
print(f"Cartas barajadas: {cartas}")

# %% [markdown]
# #### 🍀 Ejercicio: Lotería
#
# Escriba un programa en Python que simule un sorteo de lotería. El programa debe generar un número aleatorio del 0 al 99 y una serie aleatoria del 0 al 999. Luego, pida al usuario que ingrese su número y su serie.
#
# El programa comparará los valores ingresados con los sorteados y mostrará un mensaje indicando si acertó el número, la serie o ambos. Por ejemplo:
# - Si acierta solo el número, mostrar: “¡Acertó el número!”
# - Si acierta solo la serie: “¡Acertó la serie!”
# - Si acierta ambos: “¡Felicidades, acertó el premio mayor!”.
#
# Para generar los valores aleatorios, use la biblioteca random, por ejemplo random.randint(0,99) para el número y random.randint(0,999) para la serie.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
import random

def main() -> None:
    numero_sorteado, serie_sorteada = generar_numero_serie()
    numero_usuario = pedir_entero("Ingrese su número (0-99): ", 0, 99)
    serie_usuario = pedir_entero("Ingrese su serie (0-999): ", 0, 999)
    mostrar_resultados(numero_sorteado, serie_sorteada)
    comprobar_aciertos(numero_usuario, serie_usuario, numero_sorteado, serie_sorteada)

def generar_numero_serie() -> tuple:
    """Genera y devuelve (numero, serie) aleatorios."""
    return random.randint(0, 99), random.randint(0, 999)

def pedir_entero(prompt: str, minimo: int, maximo: int) -> int:
    """Pide un entero al usuario validando que esté en [minimo, maximo]."""
    terminado = False
    while not terminado:
        try:
            valor = int(input(prompt))
            if minimo <= valor <= maximo:
                terminado = True
            else:
                print(f"Por favor ingrese un número entre {minimo} y {maximo}.")
        except ValueError:
            print("Entrada no válida. Introduzca un número entero.")

    return valor

def formatear_numero_serie(numero: int, serie: int) -> tuple:
    """Devuelve las representaciones con ceros a la izquierda."""
    return (f"{numero:02d}", f"{serie:03d}")

def mostrar_resultados(numero_sorteado: int, serie_sorteada: int) -> None:
    """Imprime los valores sorteados formateados."""
    num_str, ser_str = formatear_numero_serie(numero_sorteado, serie_sorteada)
    print(f"\nNúmero sorteado: {num_str}")
    print(f"Serie sorteada: {ser_str}\n")

def comprobar_aciertos(numero_usuario: int, serie_usuario: int,
                       numero_sorteado: int, serie_sorteada: int) -> None:
    """Comprueba y muestra el mensaje correspondiente según los aciertos."""
    if numero_usuario == numero_sorteado and serie_usuario == serie_sorteada:
        print("¡Felicidades, acertó el premio mayor!")
    elif numero_usuario == numero_sorteado:
        print("¡Acertó el número!")
    elif serie_usuario == serie_sorteada:
        print("¡Acertó la serie!")
    else:
        print("Lo siento, no acertó ninguno.")

# %%
# Llamada al main para ejecutar el programa
main()

# %% [markdown]
# **3. La Biblioteca `datetime`**
#
# Permite trabajar con fechas y horas.
#
# ---

# %%
from datetime import datetime, date

# Obtener la fecha y hora actual
ahora = datetime.now()
print(f"Fecha y hora actual: {ahora}")

# Fecha sin hora
ahora_alt = date.today()
print(f"Fecha actual (solo fecha): {ahora_alt}")

# %%
# Crear una fecha específica
fecha_evento = date(2025, 9, 18)
print(f"Fecha del evento: {fecha_evento}")

# %%
# Formatear una fecha a un string más legible
print(f"Fecha formateada: {ahora.strftime('%A, %d de %B de %Y - %H:%M')}") # strftime -> string format time

# %%
# Calcular la diferencia entre dos fechas
diferencia = ahora.date() - fecha_evento
print(f"Días hasta el evento: {-diferencia.days}")

# %%
# Hacer comparaciones entre fechas
if ahora.date() < fecha_evento:
    print("El evento aún no ha ocurrido.")
elif ahora.date() == fecha_evento:
    print("¡El evento es hoy!")
else:
    print("El evento ya ha pasado.")

# %% [markdown]
# #### 👵 Ejercicio: Edad
#
# Escriba un programa en Python que calcule la edad de una persona solo en años completos. El programa debe pedir al usuario que ingrese su fecha de nacimiento en formato `DD/MM/AAAA`y luego mostrar cuántos años tiene hasta la fecha de hoy.
#
# El cálculo debe considerar si la persona ya cumplió años este año o no, para que la edad refleje únicamente los años completos vividos.
#
# Use la biblioteca `datetime` para convertir la cadena de entrada en un objeto de fecha y obtener la fecha actual.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
from datetime import datetime, date

def calcular_edad(fecha_nac_str: str) -> int:
    """
    Calcula la edad en años a partir de la fecha de nacimiento proporcionada.

    Args:
        fecha_nac_str (str): La fecha de nacimiento en formato "DD/MM/AAAA".

    Returns:
        int: La edad en años.
    """
    # strptime -> string parse time
    fecha_nac = datetime.strptime(fecha_nac_str, "%d/%m/%Y").date()
    hoy = date.today()
    años = hoy.year - fecha_nac.year
    if (hoy.month, hoy.day) < (fecha_nac.month, fecha_nac.day):
        años -= 1
    return años


def main() -> None:
    """Función principal: punto de entrada del programa."""
    fecha_usuario = input("Ingrese su fecha de nacimiento (DD/MM/AAAA): ")
    años = calcular_edad(fecha_usuario)
    print(f"Usted tiene {años} años.")


main()

# %% [markdown]
# # 📚 Otras bibliotecas comunes de Python
#
# ---
#
# ## 🔢 Matemática y Ciencia
#
# | Biblioteca       | Propósito                                                                 | Documentación                                                                 |
# |------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | `math`           | Funciones matemáticas básicas y avanzadas                                 | [docs.python.org](https://docs.python.org/3/library/math.html)                |
# | `random`         | Generación de números pseudoaleatorios y selección aleatoria               | [docs.python.org](https://docs.python.org/3/library/random.html)              |
# | `statistics`     | Funciones estadísticas básicas para datos numéricos                       | [docs.python.org](https://docs.python.org/3/library/statistics.html)         |
# | `numpy`          | Álgebra lineal, matrices y operaciones vectorizadas                       | [numpy.org](https://numpy.org/doc/)                                           |
# | `scipy`          | Herramientas científicas avanzadas, incluyendo estadísticas y optimización | [docs.scipy.org](https://docs.scipy.org/doc/scipy/)                           |
#
#
# ## 🕒 Fechas y Tiempo
#
# | Biblioteca       | Propósito                                                                 | Documentación                                                                 |
# |------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | `datetime`       | Clases para manipular fechas y horas                                     | [docs.python.org](https://docs.python.org/3/library/datetime.html)            |
# | `time`           | Funciones relacionadas con el tiempo y conversiones                       | [docs.python.org](https://docs.python.org/3/library/time.html)                |
# | `dateutil`       | Extensiones poderosas para el módulo `datetime`                           | [dateutil.readthedocs.io](https://dateutil.readthedocs.io/)                   |
#
#
# ## 📊 Manejo de Datos
#
# | Biblioteca       | Propósito                                                                 | Documentación                                                                 |
# |------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | `pandas`         | Análisis y manipulación de datos tabulares                                | [pandas.pydata.org](https://pandas.pydata.org/pandas-docs/stable/)            |
# | `csv`            | Lectura y escritura de archivos CSV                                       | [docs.python.org](https://docs.python.org/3/library/csv.html)                 |
# | `json`           | Codificación y decodificación de datos JSON                               | [docs.python.org](https://docs.python.org/3/library/json.html)                |
#
#
# ## 🌐 Web y Redes
#
# | Biblioteca       | Propósito                                                                 | Documentación                                                                 |
# |------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | `requests`       | Realizar peticiones HTTP de manera sencilla                              | [requests.readthedocs.io](https://requests.readthedocs.io/)                   |
# | `BeautifulSoup`  | Extracción de datos de archivos HTML y XML                               | [beautiful-soup-4.readthedocs.io](https://beautiful-soup-4.readthedocs.io/)   |
#
#
# ## 📈 Visualización
#
# | Biblioteca       | Propósito                                                                 | Documentación                                                                 |
# |------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | `matplotlib`     | Creación de gráficos estáticos en 2D                                      | [matplotlib.org](https://matplotlib.org/stable/contents.html)                 |
# | `seaborn`        | Visualización estadística basada en `matplotlib`                          | [seaborn.pydata.org](https://seaborn.pydata.org/)                             |
# | `plotly`         | Creación de gráficos interactivos                                         | [plotly.com](https://plotly.com/python/)                                      |
#
#
# ## ⚙️ Sistema y Utilidades
#
# | Biblioteca       | Propósito                                                                 | Documentación                                                                 |
# |------------------|---------------------------------------------------------------------------|-------------------------------------------------------------------------------|
# | `os`             | Interacción con el sistema operativo, manejo de archivos y directorios    | [docs.python.org](https://docs.python.org/3/library/os.html)                  |
# | `sys`            | Acceso a parámetros y funciones del intérprete de Python                   | [docs.python.org](https://docs.python.org/3/library/sys.html)                 |
# | `re`             | Expresiones regulares para búsqueda y manipulación de texto               | [docs.python.org](https://docs.python.org/3/library/re.html)                  |

# %% [markdown]
# ### Consideraciones
#
# No todas las bibliotecas vienen instaladas por defecto en el entorno de Python. Por ejemplo, en Colab, ya vienen muchas bibliotecas comunes instaladas, pero si se trabaja en VS Code, algunas de estas van a tener que ser instaladas.
#
# Para ello, se usa el siguiente comando desde una terminal:
#
# ```bash
# pip install NOMBRE_DEL_PAQUETE
# ```
#
# Por ejemplo, `pip install numpy`.
#
# ---

# %% [markdown]
# En los notebooks de jupyter (como este), se debe usar `!` antes de poner cualquier comando que se quiere ejecutar **en terminal**, pues no se cuenta con una terminal explícitamente.
#
# Por lo tanto, la instalación de paquetes se vería como:

# %%
# !pip install numpy

# %% [markdown]
# ## Ejercicios Adicionales
#
# ---

# %% [markdown]
# **1. Calculadora de Círculo**
#
# Use la biblioteca `math` para crear una función que reciba el radio de un círculo y devuelva una tupla con su área y su circunferencia. (Use `math.pi`).
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
import math

def calcular_circulo(radio: float) -> tuple[float, float]:
    """Calcula el área y la circunferencia de un círculo dado su radio.

    Args:
        radio (float): El radio del círculo.

    Returns:
        tuple: Un tuple que contiene el área y la circunferencia del círculo.
    """
    area = math.pi * (radio ** 2)
    circunferencia = 2 * math.pi * radio
    return (area, circunferencia)


def main() -> None:
    """Función principal: punto de entrada del programa."""
    radio_circulo = 5.0
    area_calc, circunf_calc = calcular_circulo(radio_circulo)
    print(f"Para un círculo de radio {radio_circulo}:")
    print(f"  Área: {area_calc:.2f}")
    print(f"  Circunferencia: {circunf_calc:.2f}")


main()

# %% [markdown]
# **2. Generador de Contraseñas Simple**
#
# Use las bibliotecas `random` y `string` para crear una función que genere una contraseña aleatoria de una longitud determinada.
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
import random
import string

def generar_contrasena(longitud: int) -> str:
    """Genera una contraseña aleatoria con letras, números y símbolos.

    Args:
        longitud (int): La longitud deseada de la contraseña.

    Returns:
        str: Una contraseña aleatoria de la longitud especificada.
    """
    caracteres = string.ascii_letters + string.digits + string.punctuation
    contrasena = ''.join(random.choice(caracteres) for i in range(longitud))
    return contrasena


def main() -> None:
    """Función principal: punto de entrada del programa."""
    longitud_deseada = 12
    nueva_contrasena = generar_contrasena(longitud_deseada)
    print(f"Tu nueva contraseña de {longitud_deseada} caracteres es: {nueva_contrasena}")


main()

# %% [markdown]
# **3. ¿Qué día de la semana naciste?**
#
# Use la biblioteca `datetime` para averiguar qué día de la semana fue una fecha específica (por ejemplo, su fecha de nacimiento).
#
# ---
#
# **Nota:** su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %%
import datetime

def dia_de_la_semana_nacimiento(anio: int, mes: int, dia: int) -> str:
    """Determina el día de la semana en que nació una persona.

    Args:
        anio (int): El año de nacimiento.
        mes (int): El mes de nacimiento.
        dia (int): El día de nacimiento.

    Returns:
        str: El nombre del día de la semana en que nació.
    """
    try:
        fecha = datetime.date(anio, mes, dia)
        # %A devuelve el nombre completo del día de la semana
        return fecha.strftime("%A")
    except ValueError:
        return "Fecha no válida."


def main() -> None:
    """Función principal: punto de entrada del programa."""
    dia_semana = dia_de_la_semana_nacimiento(2000, 1, 15)
    print(f"El 15 de enero de 2000 fue un: {dia_semana}")


main()

# %% [markdown]
# ## 🎯 Resumen y Ejercicios de Repaso
#
# Se presentó una síntesis de las bibliotecas en Python.
#
# ### 📚 Contenidos revisados
#
# 1. **Concepto de biblioteca:**
#    - Qué es una biblioteca y por qué es útil en programación.
#    - Diferencia entre la biblioteca estándar y bibliotecas de terceros.
#
# 2. **Exploración de documentación:**
#    - Cómo buscar y leer la documentación oficial de una biblioteca.
#    - Uso de la función `help()` y la ayuda contextual en el editor.
#
# 3. **Importación de bibliotecas:**
#    - Diferentes formas de importar (`import`, `from ... import`, `as`).
#    - Ventajas y desventajas de cada forma.
#
# ---

# %% [markdown]
# ## 📝 Ejercicios de Práctica
#
# A continuación se proponen ejercicios organizados por tema para consolidar los conceptos. **En algunos ejercicios tendrá que investigar en la web cómo hacer ciertas cosas que pide el ejercicio**.
#
# **Nota:** salvo que se indique lo contrario, su solución debe estar organizada con una función `main()` que actúe como punto de entrada del programa, junto con una llamada a `main()` al final del archivo para iniciar la ejecución.

# %% [markdown]
# ### Pruebas automáticas
#
# **EJECUTE LA CELDA DE ABAJO ANTES DE EMPEZAR A EJECUTAR SU CÓDIGO**
# Esto sirve para que pueda ejecutar casos de prueba sobre su código.
#
# ---

# %%
# !pip install --upgrade --force-reinstall notebook-cell-tester --q

# %% [markdown]
# -----
#
# ### 1️⃣ **Ejercicios: Concepto de bibliotecas**

# %% [markdown]
# **Ejercicio 1.1 — Identificación de bibliotecas estándar**
#
# Pídale al usuario que ingrese el nombre de un módulo que considere parte de la biblioteca estándar de Python.
#
# - Si el módulo ingresado es `math`, `os` o `random`, imprima un mensaje que confirme que es parte de la biblioteca estándar.
# - En caso contrario, imprima un mensaje que sugiera que podría ser una biblioteca de terceros o que no existe.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use `input()` para leer el nombre del módulo ingresado por el usuario
# - Use el operador `in` sobre una tupla, por ejemplo `nombre_modulo in ("math", "os", "random")`, para verificar la pertenencia
# - Use una estructura `if`/`else` para decidir cuál mensaje imprimir
# - Use f-strings (`f"..."`) para construir los mensajes con el nombre del módulo incluido
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Reconoce 'math' como biblioteca estándar", test_type="regex_output",
                 stdin_input="math\n", pattern=r"(?i)est[aá]ndar",
                 success_message="Reconoce correctamente que 'math' es parte de la biblioteca estándar.",
                 error_message="Al ingresar 'math' se esperaba un mensaje confirmando que es parte de la biblioteca estándar. Revise la comparación con la lista de módulos conocidos."),
        TestCase(name="Reconoce 'os' como biblioteca estándar", test_type="regex_output",
                 stdin_input="os\n", pattern=r"(?i)est[aá]ndar",
                 success_message="Reconoce correctamente que 'os' es parte de la biblioteca estándar.",
                 error_message="Al ingresar 'os' se esperaba un mensaje confirmando que es parte de la biblioteca estándar."),
        TestCase(name="Reconoce 'random' como biblioteca estándar", test_type="regex_output",
                 stdin_input="random\n", pattern=r"(?i)est[aá]ndar",
                 success_message="Reconoce correctamente que 'random' es parte de la biblioteca estándar.",
                 error_message="Al ingresar 'random' se esperaba un mensaje confirmando que es parte de la biblioteca estándar."),
    ]),
    TestSection("Sección 2 — Casos límite", [
        TestCase(name="No confirma módulos desconocidos como estándar", test_type="regex_output",
                 stdin_input="requests\n", pattern=r"(?i)(tercero|no existe)",
                 success_message="Maneja correctamente un módulo que no está en la lista, sugiriendo que es de terceros o no existe.",
                 error_message="Al ingresar 'requests' (que no es 'math', 'os' ni 'random') se esperaba un mensaje que sugiera que es una biblioteca de terceros o que no existe."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
def es_biblioteca_estandar_conocida(nombre_modulo: str) -> bool:
    """Indica si el nombre corresponde a una de las bibliotecas estándar conocidas.

    Args:
        nombre_modulo (str): El nombre del módulo ingresado por el usuario.

    Returns:
        bool: True si es 'math', 'os' o 'random'; False en caso contrario.
    """
    return nombre_modulo in ("math", "os", "random")


def main() -> None:
    """Función principal: punto de entrada del programa."""
    nombre_modulo = input("Ingrese el nombre de un módulo: ")
    if es_biblioteca_estandar_conocida(nombre_modulo):
        print(f"'{nombre_modulo}' es parte de la biblioteca estándar de Python.")
    else:
        print(f"'{nombre_modulo}' podría ser una biblioteca de terceros o no existir.")


main()

# %% [markdown]
# **Ejercicio 1.2 — Distinción de funcionalidades**
#
# Cree un programa que importe la biblioteca `math` y la biblioteca `os`.
#
# - Use una función de la biblioteca `math` para calcular la raíz cuadrada de un número ingresado por el usuario.
# - Use una función de la biblioteca `os` para obtener el directorio de trabajo actual.
# - Imprima ambos resultados y explique brevemente (por ejemplo, en un comentario) la diferencia entre las funcionalidades que ofrecen estas dos bibliotecas.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use `import math` e `import os` al inicio del programa
# - Use `math.sqrt(numero)` para calcular la raíz cuadrada
# - Use `os.getcwd()` para obtener el directorio de trabajo actual
# - Recuerde convertir la entrada del usuario con `float()` antes de calcular la raíz
# - Agregue un comentario o docstring que explique la diferencia entre ambas bibliotecas
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="La raíz cuadrada de 16 se calcula correctamente", test_type="regex_output",
                 stdin_input="16\n", pattern=r"\b4(\.0+)?\b",
                 success_message="Calcula correctamente la raíz cuadrada de 16 (4).",
                 error_message="Con el número 16, se esperaba encontrar el valor 4 (su raíz cuadrada) en la salida. Revise que está usando math.sqrt sobre el número ingresado."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="Usa math.sqrt para la raíz cuadrada", test_type="regex",
                 pattern=r"math\.sqrt\(",
                 success_message="Usa correctamente math.sqrt para calcular la raíz cuadrada.",
                 error_message="El ejercicio pide usar una función de la biblioteca math (math.sqrt) para calcular la raíz cuadrada."),
        TestCase(name="Usa os.getcwd para el directorio actual", test_type="regex",
                 pattern=r"os\.getcwd\(\)",
                 success_message="Usa correctamente os.getcwd() para obtener el directorio de trabajo actual.",
                 error_message="El ejercicio pide usar una función de la biblioteca os (os.getcwd()) para obtener el directorio de trabajo actual."),
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
import math
import os


def main() -> None:
    """Función principal: punto de entrada del programa.

    math ofrece funciones matemáticas (como sqrt), mientras que os permite
    interactuar con el sistema operativo (como consultar el directorio de
    trabajo actual): son funcionalidades completamente distintas.
    """
    numero = float(input("Ingrese un número: "))
    raiz = math.sqrt(numero)
    directorio_actual = os.getcwd()

    print(f"La raíz cuadrada de {numero} es: {raiz}")
    print(f"El directorio de trabajo actual es: {directorio_actual}")


main()

# %% [markdown]
# -----
#
# ### 2️⃣ **Ejercicios: Exploración de documentación de bibliotecas**

# %% [markdown]
# **Ejercicio 2.1 — Búsqueda de función específica**
#
# El usuario necesita generar un número entero aleatorio dentro de un rango específico.
#
# Simule la búsqueda en la documentación de la biblioteca `random`: identifique qué función usaría para este propósito y cómo se usaría, incluyendo un ejemplo de código.
#
# - Guarde el nombre de la función identificada (tal como aparece en la documentación, por ejemplo `"randint"`) en una variable `nombre_funcion`.
# - Guarde un ejemplo de cómo se llamaría esa función (como cadena de texto, por ejemplo `"random.randint(1, 10)"`) en una variable `ejemplo_de_uso`.
#
# Pista: no necesita importar la biblioteca ni ejecutar la función, solo describir el proceso de cómo encontraría la solución.
#
# ---
#
# **Nota:** este ejercicio no requiere una función `main()`, ya que consiste en investigar y registrar una respuesta, no en escribir un programa interactivo.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Consulte la documentación oficial de la biblioteca `random`: https://docs.python.org/3/library/random.html
# - Busque en esa página la función pensada para generar un entero aleatorio dentro de un rango cerrado (incluye ambos extremos)
# - El nombre de la función va como cadena de texto en `nombre_funcion`, por ejemplo `"nombre_de_la_funcion"`
# - El ejemplo de uso también es una cadena de texto en `ejemplo_de_uso`, por ejemplo `"random.nombre_de_la_funcion(1, 10)"`
# - No necesita hacer `import random` ni ejecutar nada: solo describir lo que encontró en la documentación
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 5 — Variables", [
        TestCase(name="nombre_funcion identifica 'randint'", test_type="variable",
                 variable_name="nombre_funcion",
                 validator=lambda v: isinstance(v, str) and "randint" in v.lower(),
                 error_message="'nombre_funcion' = {value}. Se esperaba que identificara la función 'randint' del módulo random, que es la que genera un entero aleatorio dentro de un rango.",
                 success_message="Identifica correctamente 'randint' como la función a usar."),
        TestCase(name="ejemplo_de_uso muestra cómo se llamaría la función", test_type="variable",
                 variable_name="ejemplo_de_uso",
                 validator=lambda v: isinstance(v, str) and "randint(" in v.lower(),
                 error_message="'ejemplo_de_uso' = {value}. Se esperaba un ejemplo de código que muestre cómo se llama a randint(), por ejemplo 'random.randint(1, 10)'.",
                 success_message="Incluye un ejemplo válido de cómo llamar a randint()."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
nombre_funcion = "randint"
ejemplo_de_uso = "random.randint(1, 10)  # genera un entero aleatorio entre 1 y 10, ambos incluidos"

# %% [markdown]
# **Ejercicio 2.2 — Comprensión de un módulo**
#
# El módulo `datetime` de Python es muy útil para trabajar con fechas y horas. Revise la documentación del módulo.
#
# Describa tres clases o funciones clave que encontraría en este módulo y explique brevemente para qué se usa cada una, basándose en lo que aprendería de su documentación.
#
# Por ejemplo: `datetime.datetime` es una clase que representa una combinación de fecha y hora.
#
# Guarde sus tres respuestas en la variable `elementos_datetime`, como una lista de tuplas `(nombre, descripcion)`.
#
# ---
#
# **Nota:** este ejercicio no requiere una función `main()`, ya que consiste en investigar y registrar una respuesta, no en escribir un programa interactivo.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Consulte la documentación oficial del módulo `datetime`: https://docs.python.org/3/library/datetime.html
# - Revise la sección de tipos disponibles (por ejemplo clases para representar solo fecha, solo hora, fecha y hora combinadas, o una duración)
# - Guarde cada hallazgo como una tupla `(nombre, descripcion)`, por ejemplo `("datetime.date", "...")`
# - La variable `elementos_datetime` debe ser una lista con exactamente tres de esas tuplas
# - No necesita importar `datetime` ni escribir una función `main()`: solo registrar lo investigado
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()


def _validar_elementos_datetime(valor) -> bool:
    """Verifica que sea una colección de al menos 3 pares (nombre, descripción)."""
    if not isinstance(valor, (list, tuple)) or len(valor) < 3:
        return False
    for item in valor:
        if not isinstance(item, (list, tuple)) or len(item) != 2:
            return False
        nombre, descripcion = item
        if not isinstance(nombre, str) or not isinstance(descripcion, str):
            return False
        if len(descripcion.strip()) < 10:
            return False
    return True


tests = [
    TestSection("Sección 5 — Variables", [
        TestCase(name="elementos_datetime describe al menos 3 elementos", test_type="variable",
                 variable_name="elementos_datetime",
                 validator=_validar_elementos_datetime,
                 error_message="'elementos_datetime' = {value}. Se esperaba una lista con al menos 3 tuplas (nombre, descripción), donde cada descripción explique brevemente para qué sirve ese elemento del módulo datetime.",
                 success_message="Describe correctamente al menos 3 elementos clave del módulo datetime."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
elementos_datetime = [
    ("datetime.datetime", "Clase que representa una combinación de fecha y hora."),
    ("datetime.date", "Clase que representa únicamente una fecha (año, mes, día), sin hora."),
    ("datetime.timedelta", "Clase que representa una duración: la diferencia entre dos fechas u horas."),
]

# %% [markdown]
# -----
#
# ### 3️⃣ **Ejercicios: Importación de bibliotecas a un programa de elaboración propia**

# %% [markdown]
# **Ejercicio 3.1 — Importación completa y uso**
#
# Escriba un programa que importe completamente la biblioteca `math` (`import math`).
#
# - Pídale al usuario que ingrese el radio de un círculo.
# - Use la constante `math.pi` y la función `math.pow` para calcular y mostrar el área del círculo.
# - Recuerde la fórmula del área: `Área = pi * radio**2`.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use `import math` para tener acceso a todo el contenido del módulo mediante el prefijo `math.`
# - Use `input()` y conviértalo con `float()` para leer el radio
# - Use la constante `math.pi` y la función `math.pow(radio, 2)` para elevar el radio al cuadrado
# - Multiplique ambos valores para obtener el área y muéstrela con `print()`, por ejemplo con formato `f"{area:.2f}"`
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Radio 5 produce un área de ~78.54", test_type="regex_output",
                 stdin_input="5\n", pattern=r"78\.5",
                 success_message="Calcula correctamente el área para un radio de 5 (≈78.54).",
                 error_message="Con radio 5, el área esperada es pi * 5**2 ≈ 78.54, pero no se encontró ese valor en la salida. Revise la fórmula (math.pi * math.pow(radio, 2))."),
        TestCase(name="Radio 1 produce un área de ~3.14", test_type="regex_output",
                 stdin_input="1\n", pattern=r"3\.14",
                 success_message="Calcula correctamente el área para un radio de 1 (≈3.14).",
                 error_message="Con radio 1, el área esperada es pi * 1**2 ≈ 3.14, pero no se encontró ese valor en la salida."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="Usa math.pow para elevar al cuadrado", test_type="regex",
                 pattern=r"math\.pow\(",
                 success_message="Usa correctamente math.pow, tal como pide el enunciado.",
                 error_message="El ejercicio pide usar explícitamente la función math.pow para calcular radio al cuadrado."),
        TestCase(name="Usa math.pi para la constante pi", test_type="regex",
                 pattern=r"math\.pi",
                 success_message="Usa correctamente math.pi, tal como pide el enunciado.",
                 error_message="El ejercicio pide usar explícitamente la constante math.pi en el cálculo del área."),
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
import math


def main() -> None:
    """Función principal: punto de entrada del programa."""
    radio = float(input("Ingrese el radio del círculo: "))
    area = math.pi * math.pow(radio, 2)
    print(f"El área del círculo es: {area:.2f}")


main()

# %% [markdown]
# **Ejercicio 3.2 — Importación parcial y alias**
#
# Escriba un programa que importe solo la función `randint` del módulo `random` y le dé un alias (`rnd_int`).
#
# - El programa debe generar un número entero aleatorio entre 1 y 100, usando el alias `rnd_int`.
# - Pídale al usuario que adivine el número.
# - Compare la respuesta del usuario con el número generado y diga si adivinó correctamente o no.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use `from random import randint as rnd_int` para importar solo esa función con un alias
# - Llame a `rnd_int(1, 100)` para generar el número secreto (ya no se usa el prefijo `random.`)
# - Use `input()` y `int()` para leer el intento del usuario
# - Compare ambos números con `if`/`else` y muestre el mensaje correspondiente
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Informa si el intento fue correcto o incorrecto", test_type="regex_output",
                 stdin_input="50\n", pattern=r"(?i)(correcta|correctamente|incorrecta|incorrectamente)",
                 success_message="Muestra correctamente si el usuario acertó o no el número.",
                 error_message="Se esperaba un mensaje indicando si el intento del usuario fue correcto o incorrecto al compararlo con el número generado con rnd_int."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="Importa randint con el alias rnd_int", test_type="regex",
                 pattern=r"from\s+random\s+import\s+randint\s+as\s+rnd_int",
                 success_message="Importa correctamente randint con el alias rnd_int.",
                 error_message="El ejercicio pide importar únicamente la función randint del módulo random, usando el alias 'rnd_int' (from random import randint as rnd_int)."),
        TestCase(name="Usa el alias rnd_int para generar el número", test_type="regex",
                 pattern=r"rnd_int\(",
                 success_message="Usa correctamente el alias rnd_int para generar el número aleatorio.",
                 error_message="Se esperaba que el número aleatorio se generara llamando a rnd_int(...), el alias importado."),
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
from random import randint as rnd_int


def main() -> None:
    """Función principal: punto de entrada del programa."""
    numero_secreto = rnd_int(1, 100)
    intento_usuario = int(input("Adivine el número (entre 1 y 100): "))

    if intento_usuario == numero_secreto:
        print("¡Adivinó correctamente!")
    else:
        print(f"Adivinó incorrectamente. El número era {numero_secreto}.")


main()

# %% [markdown]
# -----
#
# ### 4️⃣ **Ejercicios: Ejercicios integrados**

# %% [markdown]
# **Ejercicio 4.1 — Conversor de unidades de temperatura**
#
# Cree un programa que use la biblioteca `math` para convertir temperaturas de Celsius a Fahrenheit.
#
# - El programa debe pedirle al usuario que ingrese una temperatura en grados Celsius.
# - Use la fórmula de conversión: `Fahrenheit = (Celsius * 9/5) + 32`.
# - Pídale al usuario un número de precisión (cantidad de decimales) y use la función `math.ceil` o `math.floor` para redondear el resultado a esa cantidad de decimales.
# - Imprima el resultado final.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use `import math` para acceder a `math.ceil` y `math.floor`
# - Lea la temperatura con `input()` y `float()`, y la precisión con `input()` e `int()`
# - Aplique la fórmula `fahrenheit = (celsius * 9/5) + 32`
# - Para redondear a una cantidad arbitraria de decimales, multiplique por una potencia de 10 (por ejemplo `10 ** precision`), aplique `math.ceil` o `math.floor`, y luego divida entre esa misma potencia de 10
# - Muestre el resultado final con `print()`
#
# </details>

# %%
# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="0°C equivale a 32°F", test_type="regex_output",
                 stdin_input="0\n2\n", pattern=r"32(\.0+)?",
                 success_message="Convierte correctamente 0°C a 32°F.",
                 error_message="0°C equivalen a 32°F, pero no se encontró ese valor en la salida. Revise la fórmula F = C * 9/5 + 32."),
        TestCase(name="100°C equivale a 212°F", test_type="regex_output",
                 stdin_input="100\n2\n", pattern=r"212(\.0+)?",
                 success_message="Convierte correctamente 100°C a 212°F.",
                 error_message="100°C equivalen a 212°F, pero no se encontró ese valor en la salida."),
    ]),
    TestSection("Sección 2 — Casos límite", [
        TestCase(name="-40°C equivale a -40°F", test_type="regex_output",
                 stdin_input="-40\n2\n", pattern=r"-40(\.0+)?",
                 success_message="Maneja correctamente temperaturas negativas (-40°C equivalen a -40°F, el punto donde ambas escalas coinciden).",
                 error_message="-40°C equivalen a -40°F. No se encontró ese valor en la salida; revise que su fórmula funcione también con números negativos."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="Usa math.ceil o math.floor para redondear", test_type="regex",
                 pattern=r"math\.(ceil|floor)\(",
                 success_message="Usa math.ceil o math.floor, tal como pide el enunciado.",
                 error_message="El ejercicio pide usar explícitamente math.ceil o math.floor para redondear el resultado a la precisión indicada por el usuario."),
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
import math


def main() -> None:
    """Función principal: punto de entrada del programa."""
    celsius = float(input("Ingrese una temperatura en grados Celsius: "))
    precision = int(input("Ingrese el número de decimales de precisión: "))

    fahrenheit = (celsius * 9 / 5) + 32
    factor = 10 ** precision
    fahrenheit_redondeado = math.ceil(fahrenheit * factor) / factor

    print(f"{celsius}°C equivalen a {fahrenheit_redondeado}°F.")


main()

# %% [markdown]
# -----
#
# ### 5️⃣ **Ejercicios: Ejercicios de Repaso**

# %% [markdown]
# **Ejercicio 5.1 — Análisis de datos con `csv`**
#
# Use la biblioteca `csv` para leer y procesar un archivo de datos.
#
# La celda de código de abajo ya crea, en la sección **NO MODIFICAR**, un archivo llamado `ventas.csv` con el siguiente contenido:
#
# ```
# producto,cantidad
# manzana,10
# banana,15
# manzana,5
# pera,20
# ```
#
# Complete el programa para que:
#
# - Lea el archivo `ventas.csv` y calcule el total de ventas de cada producto.
# - Use un diccionario para almacenar los totales (por ejemplo: `{'manzana': 15, 'banana': 15, 'pera': 20}`).
# - Imprima el diccionario final.

# %% [markdown]
# <details>
# <summary><b>💡 Pistas</b> (haga clic para expandir)</summary>
#
# - Use `import csv` para acceder a las herramientas de lectura de archivos CSV
# - Abra el archivo con `open("ventas.csv", newline="")` (el parámetro `newline=""` es la forma recomendada al trabajar con `csv`)
# - Use `csv.DictReader(archivo)` para leer cada fila como un diccionario con claves `"producto"` y `"cantidad"`
# - Recuerde convertir `fila["cantidad"]` con `int()`, ya que el `csv` siempre entrega texto
# - Use `diccionario.get(producto, 0)` para acumular el total de cada producto, incluso la primera vez que aparece
#
# </details>

# %%
# NO MODIFICAR: crea el archivo ventas.csv necesario para este ejercicio
with open("ventas.csv", "w") as archivo:
    archivo.write("producto,cantidad\n")
    archivo.write("manzana,10\n")
    archivo.write("banana,15\n")
    archivo.write("manzana,5\n")
    archivo.write("pera,20\n")

# Su código acá

# %%
#@title Pruebas automáticas (solo ejecutar, no modificar)
from notebook_cell_tester.tester import ColabTestFramework, TestCase, TestSection

tester = ColabTestFramework()

tests = [
    TestSection("Sección 1 — Correctitud", [
        TestCase(name="Total de manzana es 15", test_type="regex_output",
                 pattern=r"manzana[^\n]{0,20}15",
                 success_message="Calcula correctamente el total de 'manzana' (15).",
                 error_message="Se esperaba un total de 15 para 'manzana' (10 + 5) en el diccionario impreso. Revise que está sumando todas las filas de un mismo producto."),
        TestCase(name="Total de banana es 15", test_type="regex_output",
                 pattern=r"banana[^\n]{0,20}15",
                 success_message="Calcula correctamente el total de 'banana' (15).",
                 error_message="Se esperaba un total de 15 para 'banana' en el diccionario impreso."),
        TestCase(name="Total de pera es 20", test_type="regex_output",
                 pattern=r"pera[^\n]{0,20}20",
                 success_message="Calcula correctamente el total de 'pera' (20).",
                 error_message="Se esperaba un total de 20 para 'pera' en el diccionario impreso."),
    ]),
    TestSection("Sección 4 — Estilo de código", [
        TestCase(name="Usa el módulo csv para leer el archivo", test_type="regex",
                 pattern=r"csv\.(reader|DictReader)",
                 success_message="Usa correctamente el módulo csv (csv.reader o csv.DictReader) para leer el archivo.",
                 error_message="El ejercicio pide usar la biblioteca csv (por ejemplo, csv.reader o csv.DictReader) para leer ventas.csv, en vez de procesar el texto manualmente."),
        TestCase(name="El código define la función main", test_type="regex",
                 pattern=r"def\s+main\s*\(",
                 success_message="Se definió la función main().",
                 error_message="No se encontró la función main(). Organice su solución con una función main() como punto de entrada."),
    ]),
]

tester.run_sections(tests)
tester.display_results()

# %%
#@title Posible solución (expandir para ver una solución de referencia)
# NO MODIFICAR: crea el archivo ventas.csv necesario para este ejercicio
with open("ventas.csv", "w") as archivo:
    archivo.write("producto,cantidad\n")
    archivo.write("manzana,10\n")
    archivo.write("banana,15\n")
    archivo.write("manzana,5\n")
    archivo.write("pera,20\n")

import csv


def main() -> None:
    """Función principal: punto de entrada del programa."""
    totales_por_producto = {}
    with open("ventas.csv", newline="") as archivo:
        lector = csv.DictReader(archivo)
        for fila in lector:
            producto = fila["producto"]
            cantidad = int(fila["cantidad"])
            totales_por_producto[producto] = totales_por_producto.get(producto, 0) + cantidad

    print(totales_por_producto)


main()

# %% [markdown]
# -----
#
# ### 📋 **Instrucciones para resolver:**
#
# 1.  Copie cada ejercicio en una nueva celda de código.
# 2.  Resuelva paso a paso y comente su razonamiento.
# 3.  Ejecute para verificar sus respuestas.
# 4.  Experimente modificando los valores.
# 5.  Pregunte si tiene dudas. Hágalo pensando en algoritmos.
